# %%
import sys
sys.path[0] = "/home/cooper-cooper/Desktop/vans/"

from utilities.variational import Autoencoder
import tensorflow_quantum as tfq
from utilities.qmodels import QNN,EnergyLoss

import tensorflow as tf

from utilities.evaluator import Evaluator
import numpy as np

import matplotlib.pyplot as plt
from IPython import display
from tqdm import tqdm
from utilities.variational import VQE
import cirq

from datetime import datetime

from utilities.variational import VQE
from utilities.evaluator import Evaluator
from utilities.idinserter import IdInserter
from utilities.simplifier import Simplifier
from utilities.unitary_killer_autoencoder import UnitaryMurder
from utilities.misc import scheduler_selector_temperature, scheduler_parameter_perturbation_wall #this outputs always 10 for now.

# %load_ext autoreload
# %autoreload 2

# %%
### load pure states

indexed_pure_states=[]
resolver_pure_states=[]
js=np.linspace(0.5,2.3,16)[0::3]
for bond in js:
    problem_config ={"problem" : "H2", "geometry": [('H', (0., 0., 0.)), ('H', (0., 0., bond))], "multiplicity":1, "charge":0, "basis":"sto-3g"}
    args={"n_qubits":8,"problem_config":problem_config, "load_displaying":False,"specific_folder_name":"4_bd_{}".format(bond)}
    evaluator = Evaluator(args,loading=True, path="../data-vans/")
    #energies.append(evaluator.raw_history[len(list(evaluator.raw_history.keys()))-1][-1])
    vqe_handler = VQE(n_qubits=4,noise_config={}, problem_config=problem_config,
                            return_lower_bound=True)
    _, cuener, indexed_circuit, resolver, bestener = evaluator.evolution[evaluator.get_best_iteration()]
    indexed_pure_states.append(indexed_circuit)
    resolver_pure_states.append(resolver)

# %%
auto_handler = Autoencoder(n_qubits=4,problem_config=problem_config, nb=2, lr = 1.,
                        epochs=2000, verbose=0,
                        patience=200, optimizer="adam",
                        many_indexed_circuits=indexed_pure_states, many_symbols_to_values=resolver_pure_states)

evaluator = Evaluator(args={"n_qubits":4,
                            "problem_config":{"problem":"AutoencoderH2","n_qubits":3},
                            "noise_config":{}},
                      info="", 
                      path="../data-vans/", acceptance_percentage=0.01, 
                      accuracy_to_end=0., reduce_acceptance_percentage=True)

info = "AUTOENCODEr\ntotal_qubits: {}\ntrash_qubits: {}\n".format(len(auto_handler.qubits), auto_handler.nb)
evaluator.displaying["information"]+=info


start = datetime.now()

initialization="hea"

selector_temperature=20
reps=300
rate_iids_per_step=1.0
wait_to_get_back=10

iid = IdInserter(n_qubits=len(auto_handler.qubits))
iid.selector_temperature = selector_temperature

#Simplifier reduces gates number as much as possible while keeping same expected value of target hamiltonian
Simp = Simplifier(n_qubits=len(auto_handler.qubits))

#UnitaryMuerder is in charge of evaluating changes on the energy while setting apart one (or more) parametrized gates. If
killer = UnitaryMurder(auto_handler, many_indexed_circuits=indexed_pure_states, many_symbols_to_values=resolver_pure_states, noise_config={})


indexed_circuit = auto_handler.hea_ansatz_indexed_circuit(L=3)

print("beggining to train!")
energy, symbol_to_value, training_evolution = auto_handler.autoencoder(indexed_circuit) #compute energy
#add initial info to evaluator


to_print="\nIteration #{}\nTime since beggining:{}\n best energy: {}\ncurrent_energy {}\n lower_bound: {}".format(0, datetime.now()-start, energy, energy, evaluator.accuracy_to_end)
print(to_print)
evaluator.displaying["information"]+=to_print

evaluator.add_step(indexed_circuit, symbol_to_value, energy, relevant=True)
evaluator.lowest_energy = energy

for iteration in range(1,reps+1):
    relevant=False

    ### create a mutation M (maybe this word is too fancy); we add (probably more than one) identity resolution
    iid.selector_temperature=scheduler_selector_temperature(energy, evaluator.lowest_energy, when_on=selector_temperature)
    M_indices, M_symbols_to_values, M_idx_to_symbols = iid.place_identities(indexed_circuit, symbol_to_value, rate_iids_per_step= rate_iids_per_step)

    ### simplify the circuit as much as possible
    Sindices, Ssymbols_to_values, Sindex_to_symbols = Simp.reduce_circuit(M_indices, M_symbols_to_values, M_idx_to_symbols)

    ## compute the energy of the mutated-simplified circuit [Note 1]
    MSenergy, MSsymbols_to_values, _ = auto_handler.autoencoder(
        Sindices, symbols_to_values=Ssymbols_to_values,
        parameter_perturbation_wall=scheduler_parameter_perturbation_wall(its_without_improvig=evaluator.its_without_improvig))

    if evaluator.accept_energy(MSenergy):
        indexed_circuit, symbol_to_value, index_to_symbols = Sindices, MSsymbols_to_values, Sindex_to_symbols
        # unitary slaughter: delete as many 1-qubit gates as possible, as long as the energy doesn't go up (we allow %1 increments per iteration)
        cnt=0
        reduced=True
        lmax=len(indexed_circuit)
        while reduced and cnt < lmax:
            indexed_circuit, symbol_to_value, index_to_symbols, energy, reduced = killer.unitary_slaughter(indexed_circuit, symbol_to_value, index_to_symbols)
            indexed_circuit, symbol_to_value, index_to_symbols = Simp.reduce_circuit(indexed_circuit, symbol_to_value, index_to_symbols)
            cnt+=1
        relevant=True
    evaluator.add_step(indexed_circuit, symbol_to_value, energy, relevant=relevant)

    to_print="\nIteration #{}\nTime since beggining:{}\n best energy: {}\ncurrent energy: {}\n lower_bound: {}".format(iteration, datetime.now()-start, evaluator.lowest_energy,energy, evaluator.accuracy_to_end)
    print(to_print)
    evaluator.displaying["information"]+=to_print

    evaluator.save_dicts_and_displaying()

    if evaluator.if_finish_ok is True:
        print("HOMEWORK DONE! \nBeers on me ;)")
        break

    if evaluator.its_without_improvig == wait_to_get_back:
        print("Getting back to favorite, it's been already {} iterations".format(wait_to_get_back))
        _, energy, indices, resolver, _, _ =  evaluator.evolution[evaluator.get_best_iteration()]
        evaluator.its_without_improvig = 0
# Out:
# beggining to train!
#
# Iteration #0
# Time since beggining:0:00:03.531864
#  best energy: 0.012179701589047909
# current_energy 0.012179701589047909
#  lower_bound: 0.0
#
# Iteration #1
# Time since beggining:0:01:04.992383
#  best energy: 0.003300151787698269
# current energy: 0.003300151787698269
#  lower_bound: 0.0
#
# Iteration #2
# Time since beggining:0:01:24.377513
#  best energy: 0.001759987324476242
# current energy: 0.001759987324476242
#  lower_bound: 0.0
#
# Iteration #3
# Time since beggining:0:01:27.362284
#  best energy: 0.001759987324476242
# current energy: 0.001759987324476242
#  lower_bound: 0.0
#
# Iteration #4
# Time since beggining:0:01:29.465751
#  best energy: 0.001759987324476242
# current energy: 0.001759987324476242
#  lower_bound: 0.0
#
# Iteration #5
# Time since beggining:0:01:32.228768
#  best energy: 0.001759987324476242
# current energy: 0.001759987324476242
#  lower_bound: 0.0
#
# Iteration #6
# Time since beggining:0:01:33.535709
#  best energy: 0.001759987324476242
# current energy: 0.001759987324476242
#  lower_bound: 0.0
#
# Iteration #7
# Time since beggining:0:01:35.540557
#  best energy: 0.001759987324476242
# current energy: 0.001759987324476242
#  lower_bound: 0.0
#
# Iteration #8
# Time since beggining:0:01:37.823280
#  best energy: 0.001759987324476242
# current energy: 0.001759987324476242
#  lower_bound: 0.0
#
# Iteration #9
# Time since beggining:0:01:39.008504
#  best energy: 0.001759987324476242
# current energy: 0.001759987324476242
#  lower_bound: 0.0
#
# Iteration #10
# Time since beggining:0:01:41.529086
#  best energy: 0.001759987324476242
# current energy: 0.001759987324476242
#  lower_bound: 0.0
#
# Iteration #11
# Time since beggining:0:01:43.634756
#  best energy: 0.001759987324476242
# current energy: 0.001759987324476242
#  lower_bound: 0.0
#
# Iteration #12
# Time since beggining:0:01:47.422251
#  best energy: 0.001759987324476242
# current energy: 0.001759987324476242
#  lower_bound: 0.0
# Getting back to favorite, it's been already 10 iterations
#
# Iteration #13
# Time since beggining:0:01:49.526297
#  best energy: 0.001759987324476242
# current energy: 0.001759987324476242
#  lower_bound: 0.0
#
# Iteration #14
# Time since beggining:0:01:51.525429
#  best energy: 0.001759987324476242
# current energy: 0.001759987324476242
#  lower_bound: 0.0
#
# Iteration #15
# Time since beggining:0:01:53.519555
#  best energy: 0.001759987324476242
# current energy: 0.001759987324476242
#  lower_bound: 0.0
#
# Iteration #16
# Time since beggining:0:02:12.216546
#  best energy: 0.001759987324476242
# current energy: 0.0017869509756565094
#  lower_bound: 0.0
#
# Iteration #17
# Time since beggining:0:02:31.351066
#  best energy: 0.001759987324476242
# current energy: 0.0019712125261624656
#  lower_bound: 0.0
#
# Iteration #18
# Time since beggining:0:02:35.905861
#  best energy: 0.001759987324476242
# current energy: 0.0019712125261624656
#  lower_bound: 0.0
#
# Iteration #19
# Time since beggining:0:02:51.250625
#  best energy: 0.0015678579608599346
# current energy: 0.0015678579608599346
#  lower_bound: 0.0
#
# Iteration #20
# Time since beggining:0:02:54.457773
#  best energy: 0.0015678579608599346
# current energy: 0.0015678579608599346
#  lower_bound: 0.0
#
# Iteration #21
# Time since beggining:0:02:56.371579
#  best energy: 0.0015678579608599346
# current energy: 0.0015678579608599346
#  lower_bound: 0.0
#
# Iteration #22
# Time since beggining:0:02:58.389340
#  best energy: 0.0015678579608599346
# current energy: 0.0015678579608599346
#  lower_bound: 0.0
#
# Iteration #23
# Time since beggining:0:03:00.452946
#  best energy: 0.0015678579608599346
# current energy: 0.0015678579608599346
#  lower_bound: 0.0
#
# Iteration #24
# Time since beggining:0:03:05.350066
#  best energy: 0.0015678579608599346
# current energy: 0.0015678579608599346
#  lower_bound: 0.0
#
# Iteration #25
# Time since beggining:0:03:07.676846
#  best energy: 0.0015678579608599346
# current energy: 0.0015678579608599346
#  lower_bound: 0.0
#
# Iteration #26
# Time since beggining:0:03:43.166909
#  best energy: 0.0014375435809294383
# current energy: 0.0014375435809294383
#  lower_bound: 0.0
#
# Iteration #27
# Time since beggining:0:03:46.057101
#  best energy: 0.0014375435809294383
# current energy: 0.0014375435809294383
#  lower_bound: 0.0
#
# Iteration #28
# Time since beggining:0:03:48.985492
#  best energy: 0.0014375435809294383
# current energy: 0.0014375435809294383
#  lower_bound: 0.0
#
# Iteration #29
# Time since beggining:0:03:52.415716
#  best energy: 0.0014375435809294383
# current energy: 0.0014375435809294383
#  lower_bound: 0.0
#
# Iteration #30
# Time since beggining:0:03:54.825387
#  best energy: 0.0014375435809294383
# current energy: 0.0014375435809294383
#  lower_bound: 0.0
#
# Iteration #31
# Time since beggining:0:04:00.499761
#  best energy: 0.0014375435809294383
# current energy: 0.0014375435809294383
#  lower_bound: 0.0
#
# Iteration #32
# Time since beggining:0:04:03.657461
#  best energy: 0.0014375435809294383
# current energy: 0.0014375435809294383
#  lower_bound: 0.0
#
# Iteration #33
# Time since beggining:0:04:07.791487
#  best energy: 0.0014375435809294383
# current energy: 0.0014375435809294383
#  lower_bound: 0.0
#
# Iteration #34
# Time since beggining:0:04:12.091469
#  best energy: 0.0014375435809294383
# current energy: 0.0014375435809294383
#  lower_bound: 0.0
#
# Iteration #35
# Time since beggining:0:04:14.189344
#  best energy: 0.0014375435809294383
# current energy: 0.0014375435809294383
#  lower_bound: 0.0
#
# Iteration #36
# Time since beggining:0:04:17.035732
#  best energy: 0.0014375435809294383
# current energy: 0.0014375435809294383
#  lower_bound: 0.0
# Getting back to favorite, it's been already 10 iterations
#
# Iteration #37
# Time since beggining:0:04:20.868846
#  best energy: 0.0014375435809294383
# current energy: 0.0014375435809294383
#  lower_bound: 0.0
#
# Iteration #38
# Time since beggining:0:04:25.342931
#  best energy: 0.0014375435809294383
# current energy: 0.0014375435809294383
#  lower_bound: 0.0
#
# Iteration #39
# Time since beggining:0:04:29.215386
#  best energy: 0.0014375435809294383
# current energy: 0.0014375435809294383
#  lower_bound: 0.0
#
# Iteration #40
# Time since beggining:0:04:31.930745
#  best energy: 0.0014375435809294383
# current energy: 0.0014375435809294383
#  lower_bound: 0.0
#
# Iteration #41
# Time since beggining:0:04:33.921073
#  best energy: 0.0014375435809294383
# current energy: 0.0014375435809294383
#  lower_bound: 0.0
#
# Iteration #42
# Time since beggining:0:04:36.034208
#  best energy: 0.0014375435809294383
# current energy: 0.0014375435809294383
#  lower_bound: 0.0
#
# Iteration #43
# Time since beggining:0:04:38.133362
#  best energy: 0.0014375435809294383
# current energy: 0.0014375435809294383
#  lower_bound: 0.0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-291043a12ab8> in <module>
#      70         lmax=len(indexed_circuit)
#      71         while reduced and cnt < lmax:
# ---> 72             indexed_circuit, symbol_to_value, index_to_symbols, energy, reduced = killer.unitary_slaughter(indexed_circuit, symbol_to_value, index_to_symbols)
#      73             indexed_circuit, symbol_to_value, index_to_symbols = Simp.reduce_circuit(indexed_circuit, symbol_to_value, index_to_symbols)
#      74             cnt+=1
#
# ~/Desktop/vans/utilities/unitary_killer_autoencoder.py in unitary_slaughter(self, indexed_circuit, symbol_to_value, index_to_symbols)
#      62         count=0
#      63         while reduced is True and count < max_its:
# ---> 64             indexed_circuit, symbol_to_value, index_to_symbols, energy, reduced = self.kill_one_unitary(indexed_circuit, symbol_to_value, index_to_symbols)
#      65             count+=1
#      66         return indexed_circuit, symbol_to_value, index_to_symbols, energy, reduced
#
# ~/Desktop/vans/utilities/unitary_killer_autoencoder.py in kill_one_unitary(self, indexed_circuit, symbol_to_value, index_to_symbols)
#      92                 valid, proposal_circuit, proposal_symbols_to_values, prop_cirq_circuit = self.create_proposal_without_gate(info_gate) #notice prop_cirq_circuit beomes useless if noise.-
#      93                 if valid:
# ---> 94                     proposal_energy = self.give_energy(proposal_circuit, proposal_symbols_to_values)
#      95
#      96                     if self.accepting_criteria(proposal_energy, original_energy):
#
# ~/Desktop/vans/utilities/unitary_killer_autoencoder.py in give_energy(self, indexed_circuit, symbols_to_values)
#      49
#      50         model = QNN(symbols=symbols, observable=self.observable, batch_sizes=len(qbatch))
# ---> 51         tfqcircuit=tfq.convert_to_tensor(qbatch)
#      52         model(tfqcircuit)
#      53         model.compile(loss=EnergyLoss())
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/autograph/impl/api.py in wrapper(*args, **kwargs)
#     300   def wrapper(*args, **kwargs):
#     301     with ag_ctx.ControlStatusCtx(status=ag_ctx.Status.DISABLED):
# --> 302       return func(*args, **kwargs)
#     303
#     304   if inspect.isfunction(func) or inspect.ismethod(func):
#
# ~/.local/lib/python3.6/site-packages/tensorflow_quantum/python/util.py in convert_to_tensor(items_to_convert)
#     205
#     206     # This will catch impossible dimensions
# --> 207     return tf.convert_to_tensor(recur(items_to_convert))
#     208
#     209
#
# ~/.local/lib/python3.6/site-packages/tensorflow_quantum/python/util.py in recur(items_to_convert, curr_type)
#     197                 curr_type = cirq.Circuit
#     198                 tensored_items.append(
# --> 199                     serializer.serialize_circuit(item).SerializeToString())
#     200             else:
#     201                 raise TypeError("Incompatible item passed into "
#
# ~/.local/lib/python3.6/site-packages/tensorflow_quantum/core/serialize/serializer.py in serialize_circuit(circuit_inp)
#     435         circuit[moment_ind] = new_moment
#     436
# --> 437     return SERIALIZER.serialize(circuit)
#     438
#     439
#
# ~/.local/lib/python3.6/site-packages/cirq/google/serializable_gate_set.py in serialize(self, program, msg, arg_function_language)
#     114             self._serialize_circuit(program,
#     115                                     msg.circuit,
# --> 116                                     arg_function_language=arg_function_language)
#     117             if arg_function_language is None:
#     118                 arg_function_language = (
#
# ~/.local/lib/python3.6/site-packages/cirq/google/serializable_gate_set.py in _serialize_circuit(self, circuit, msg, arg_function_language)
#     227                 self.serialize_op(op,
#     228                                   moment_proto.operations.add(),
# --> 229                                   arg_function_language=arg_function_language)
#     230
#     231     def _deserialize_circuit(
#
# ~/.local/lib/python3.6/site-packages/cirq/google/serializable_gate_set.py in serialize_op(self, op, msg, arg_function_language)
#     148                 for serializer in self.serializers[gate_type_mro]:
#     149                     proto_msg = serializer.to_proto(
# --> 150                         op, msg, arg_function_language=arg_function_language)
#     151                     if proto_msg is not None:
#     152                         return proto_msg
#
# ~/.local/lib/python3.6/site-packages/cirq/google/op_serializer.py in to_proto(self, op, msg, arg_function_language)
#     124             msg.qubits.add().id = v2.qubit_to_proto_id(qubit)
#     125         for arg in self.args:
# --> 126             value = self._value_from_gate(op, arg)
#     127             if value is not None and (not arg.default or value != arg.default):
#     128                 _arg_to_proto(value,
#
# ~/.local/lib/python3.6/site-packages/cirq/google/op_serializer.py in _value_from_gate(self, op, arg)
#     143                         gate, op_getter))
#     144         elif callable(op_getter):
# --> 145             value = op_getter(op)
#     146
#     147         if arg.required and value is None:
#
# ~/.local/lib/python3.6/site-packages/tensorflow_quantum/core/serialize/serializer.py in <lambda>(x)
#     121             serialized_name="exponent_scalar",
#     122             serialized_type=float,
# --> 123             op_getter=lambda x: _scalar_extractor(x.gate.exponent)),
#     124         cirq.google.SerializingArg(
#     125             serialized_name="global_shift",
#
# ~/.local/lib/python3.6/site-packages/tensorflow_quantum/core/serialize/serializer.py in _scalar_extractor(x)
#      72                 lhs_eval, (sympy.numbers.Float, sympy.numbers.Integer)):
#      73             # lhs contains number.
# ---> 74             return _round(float(lhs_eval))
#      75
#      76     raise ValueError("Arithmetic expression outside of simple "
#
# ~/.local/lib/python3.6/site-packages/tensorflow_quantum/core/serialize/serializer.py in _round(x)
#      29
#      30 def _round(x):
# ---> 31     return np.round(x, 6) if isinstance(x, float) else x
#      32
#      33
#
# <__array_function__ internals> in round_(*args, **kwargs)
#
# ~/.local/lib/python3.6/site-packages/numpy/core/fromnumeric.py in round_(a, decimals, out)
#    3597     around : equivalent function; see for details.
#    3598     """
# -> 3599     return around(a, decimals=decimals, out=out)
#    3600
#    3601
#
# KeyboardInterrupt:

# %% [markdown]
# Now we construct the inverse circuit.
#
# Let's say that VQE-VAns prepares the state $| \psi_i >$ as $V_i |0>$. Then VAns finds an autoencoder circuit $W$.
#
# Then we'll check at the average fidelity $\sum_i |<\psi_i| \tilde{\psi}_i> |^{2}$
#
# with  $|\tilde{\psi}_i> = (\mathcal{E} \circ \mathcal{M} \circ \mathcal{D}) \; |\psi_i>$;
#
# with $\mathcal{E} = W$, $\mathcal{D} = W^{\dagger}$ and $\mathcal{M} = \mathcal{I}_{AB} - \dfrac{1}{n_B} ( \sum_j |0>_{j_B}<0| \times \mathcal{I}_{A, \bar{j}})$

# %%
W, infidelity, indexed_circuit, resolver, best_infidelity = evaluator.evolution[evaluator.get_best_iteration()]

# %%
W = cirq.unitary(W)
Wdagger = cirq.unitary(auto_handler.give_inverse(indexed_circuit,resolver)[-1])

# %%
def compute_fidelity(input_state, encoding, channel, decoding):
    """
    we assume input_state is a ket.
    """
    st = np.dot(encoding, input_state)
    st = np.dot(channel, st)
    st = np.dot(decoding, st)
    return np.round(np.dot(np.conjugate(input_state),st), 16)

# %%
fidelities = []
for k in range(len(auto_handler.qbatch)):
    input_state = cirq.unitary(auto_handler.qbatch[k])[:,0]
    channel = np.eye(2**len(auto_handler.qubits)) - (1/auto_handler.nb)*(np.kron(np.kron(*[auto_handler.zero_proj(vqe_handler.qubits[k]).matrix() for k in range(2)]), np.eye(4)))
    fidelities.append(compute_fidelity(input_state, W, channel, Wdagger))

# %%
np.log10(1-np.mean(fidelities))
# Out:
# (-4.407120826202616+3.69644188602273e-12j)

# %% [markdown]
# Now we test on different bond lengths

# %%
bond_train=np.linspace(0.5,2.3,16)[0::3]
bond_test=[]
test_energies = []
test_states=[]
train_energies=[]
fcis=[]
fcis_test=[]
fcis_train=[]
train_states=[]
for b in tqdm(np.linspace(0.5,2.3,16)):
    problem_config ={"problem" : "H2", "geometry": [('H', (0., 0., 0.)), ('H', (0., 0., b))], "multiplicity":1, "charge":0, "basis":"sto-3g"}
    args={"n_qubits":8,"problem_config":problem_config, "load_displaying":False,"specific_folder_name":"4_bd_{}".format(b)}
    evaluator = Evaluator(args,loading=True, path="../data-vans/")
    #energies.append(evaluator.raw_history[len(list(evaluator.raw_history.keys()))-1][-1])
    vqe_handler = VQE(n_qubits=4,noise_config={}, problem_config=problem_config,
                            return_lower_bound=True)
    VAnsCircuit, cuener, indexed_circuit, resolver, bestener = evaluator.evolution[evaluator.get_best_iteration()]
    
    model = QNN(symbols=list(resolver.keys()), observable=vqe_handler.observable, batch_sizes=1)
    model.compile( loss=EnergyLoss())
    fcis.append(vqe_handler.lower_bound_energy)
    
    if not (b in bond_train):
        bond_test.append(b)
        test_energies.append(np.squeeze(model(tfq.convert_to_tensor([VAnsCircuit]))))
        fcis_test.append(vqe_handler.lower_bound_energy)
        test_states.append(cirq.unitary(VAnsCircuit)[:,0])
        
    else:
        train_states.append(cirq.unitary(VAnsCircuit)[:,0])
        
        train_energies.append(np.squeeze(model(tfq.convert_to_tensor([VAnsCircuit]))))
        fcis_train.append(vqe_handler.lower_bound_energy)
# Out:
# 100%|██████████| 16/16 [00:09<00:00,  1.74it/s]

# %%
fcisfull=[]
for b in tqdm(np.linspace(0.5,2.3,100)):
    problem_config ={"problem" : "H2", "geometry": [('H', (0., 0., 0.)), ('H', (0., 0., b))], "multiplicity":1, "charge":0, "basis":"sto-3g"}
    args={"n_qubits":8,"problem_config":problem_config, "load_displaying":False,"specific_folder_name":"4_bd_{}".format(b)}
    vqe_handler = VQE(n_qubits=4,noise_config={}, problem_config=problem_config,
                            return_lower_bound=True)
    fcisfull.append(vqe_handler.lower_bound_energy)
# Out:
# 100%|██████████| 100/100 [00:57<00:00,  1.74it/s]

# %%
plt.figure(figsize=(10,10))
plt.plot(np.linspace(0.5,2.3,100),fcisfull,color="red",linewidth=5,alpha=0.5,label="FCI")
plt.scatter(bond_train, fcis_train,s=300, color="green",label="Train points")
plt.scatter(bond_test, fcis_test, s=300,color="blue",label="Test points")
plt.xlabel("bond length",size=20)
plt.ylabel("bond length",size=20)
plt.legend(prop={"size":20})
plt.savefig(fol+"energies.png")

# %%
channel = np.eye(2**len(auto_handler.qubits)) - (1/auto_handler.nb)*(np.kron(np.kron(*[auto_handler.zero_proj(vqe_handler.qubits[k]).matrix() for k in range(2)]), np.eye(4)))

test_fidelities = []
for state in test_states:
    test_fidelities.append(compute_fidelity(state, W, channel, Wdagger))
    
train_fidelities = []
for state in train_states:
    train_fidelities.append(compute_fidelity(state, W, channel, Wdagger))

# %%
sts=["fcis_train", "fcis_test", "bond_train","bond_test", "bonds", "test_fidelities", "train_fidelities","fcisfull"]
fcis_train = np.load("results/")
fcis_test
bond_train
bond_test
np.linspace(0.5,2.3,16)
test_fidelities
train_fidelities
fcisfull

# %%
import os 
fol="results/autoencoder/H2/"
os.makedirs(fol,exist_ok=True)
sts=["fcis_train", "fcis_test", "bond_train","bond_test", "bonds", "test_fidelities", "train_fidelities","fcisfull"]
fis=[fcis_train, fcis_test, bond_train, bond_test,np.linspace(0.5,2.3,16), test_fidelities, train_fidelities,fcisfull]
for strfi, thi in zip(sts, fis):
    np.save(fol+strfi,thi)

# %%
bonds=np.linspace(0.5,2.3,16)
plt.figure(figsize=(10,10))
plt.plot(bonds,np.ones(len(bonds)),color="black",alpha=0.5,label="1")
plt.scatter(bond_train, train_fidelities, color="red",label="Train points")
plt.scatter(bond_test, test_fidelities, color="green",label="Test points")
plt.xlabel("bond length",size=20)
plt.ylabel("bond length",size=20)
plt.legend(prop={"size":20})
plt.savefig("fidelities.png")
# Out:
# /home/cooper-cooper/.local/lib/python3.6/site-packages/numpy/core/_asarray.py:138: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order, subok=True)
