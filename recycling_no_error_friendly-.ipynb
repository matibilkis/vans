# %%
import numpy as np
import sympy
import cirq
import tensorflow as tf
import tensorflow_quantum as tfq
import matplotlib.pyplot as plt
from tqdm import tqdm
import matplotlib.pyplot as plt

# %%
n_qubits = 4

qubits = cirq.GridQubit.rect(1, n_qubits)
g=1
J=1.21
observable = [-float(0.5*g)*cirq.Z.on(q) for q in qubits] 
for q in range(len(qubits)):
    observable.append(-float(0.5*J)*cirq.X.on(qubits[q])*cirq.X.on(qubits[(q+1)%len(qubits)]))

# %%
gates=[cirq.rz, cirq.rx, cirq.rz]

circuit = []
symbols=[]
for k in range(len(qubits)):
    for j in range(3):
        symbol="th_"+str(k)+"_"+str(j)
        symbols.append(symbol)
        circuit.append(gates[j](sympy.Symbol(symbol)).on(qubits[k]))
#for k in range(len(qubits)):
#    circuit.append(cirq.CNOT(qubits[k], qubits[(k+1)%len(qubits)]))
circuit = cirq.Circuit(circuit)

tfqcircuit = tfq.convert_to_tensor([circuit])

circuit_input = tf.keras.Input(shape=(), dtype=tf.string)
output = tfq.layers.Expectation(backend=cirq.DensityMatrixSimulator(noise=cirq.depolarize(0.00001)))(
circuit_input,
symbol_names=symbols,
operators=tfq.convert_to_tensor([observable]),
initializer=tf.keras.initializers.RandomNormal()) #we may change this!!!

model = tf.keras.Model(inputs=circuit_input, outputs=output)
adam = tf.keras.optimizers.Adam(learning_rate=0.01)
model.compile(optimizer=adam, loss='mse')

# %%
for k in range(25):

    qoutput = tf.ones((1, 1))*-2.*n_qubits
    
    model.set_weights([tf.random.uniform((len(symbols),))])
    model.fit(x=tfqcircuit, y=qoutput,validation_steps=None,
              steps_per_epoch=1, batch_size=1, epochs=20, verbose=1, 
              callbacks=[tf.keras.callbacks.EarlyStopping(monitor='loss', patience=5)])
# Out:
# Train on 1 samples
# Epoch 1/20
# 1/1 [==============================] - 3s 3s/sample - loss: 61.0957
# Epoch 2/20
# 1/1 [==============================] - 1s 895ms/sample - loss: 61.0598
# Epoch 3/20
# 1/1 [==============================] - 1s 859ms/sample - loss: 61.0244
# Epoch 4/20
# 1/1 [==============================] - 1s 916ms/sample - loss: 60.9897
# Epoch 5/20
# 1/1 [==============================] - 1s 715ms/sample - loss: 60.9556
# Epoch 6/20
# 1/1 [==============================] - 1s 868ms/sample - loss: 60.9223
# Epoch 7/20
# 1/1 [==============================] - 1s 943ms/sample - loss: 60.8896
# Epoch 8/20
# 1/1 [==============================] - 1s 893ms/sample - loss: 60.8578
# Epoch 9/20
# 1/1 [==============================] - 1s 860ms/sample - loss: 60.8267
# Epoch 10/20
# 1/1 [==============================] - 1s 846ms/sample - loss: 60.7965
# Epoch 11/20
# 1/1 [==============================] - 1s 908ms/sample - loss: 60.7671
# Epoch 12/20
# 1/1 [==============================] - 1s 787ms/sample - loss: 60.7385
# Epoch 13/20
# 1/1 [==============================] - 1s 808ms/sample - loss: 60.7108
# Epoch 14/20
# 1/1 [==============================] - 1s 738ms/sample - loss: 60.6839
# Epoch 15/20
# 1/1 [==============================] - 1s 881ms/sample - loss: 60.6579
# Epoch 16/20
# 1/1 [==============================] - 1s 877ms/sample - loss: 60.6327
# Epoch 17/20
# 1/1 [==============================] - 1s 925ms/sample - loss: 60.6084
# Epoch 18/20
# 1/1 [==============================] - 1s 937ms/sample - loss: 60.5848
# Epoch 19/20
# 1/1 [==============================] - 1s 821ms/sample - loss: 60.5621
# Epoch 20/20
# 1/1 [==============================] - 1s 826ms/sample - loss: 60.5401
# Train on 1 samples
# Epoch 1/20
# 1/1 [==============================] - 1s 832ms/sample - loss: 60.7005
# Epoch 2/20
# 1/1 [==============================] - 1s 897ms/sample - loss: 60.6786
# Epoch 3/20
# 1/1 [==============================] - 1s 914ms/sample - loss: 60.6560
# Epoch 4/20
# 1/1 [==============================] - 1s 834ms/sample - loss: 60.6331
# Epoch 5/20
# 1/1 [==============================] - 1s 918ms/sample - loss: 60.6100
# Epoch 6/20
# 1/1 [==============================] - 1s 952ms/sample - loss: 60.5867
# Epoch 7/20
# 1/1 [==============================] - 1s 811ms/sample - loss: 60.5635
# Epoch 8/20
# 1/1 [==============================] - 1s 751ms/sample - loss: 60.5405
# Epoch 9/20
# 1/1 [==============================] - 1s 874ms/sample - loss: 60.5176
# Epoch 10/20
# 1/1 [==============================] - 1s 942ms/sample - loss: 60.4951
# Epoch 11/20
# 1/1 [==============================] - 1s 775ms/sample - loss: 60.4728
# Epoch 12/20
# 1/1 [==============================] - 1s 768ms/sample - loss: 60.4510
# Epoch 13/20
# 1/1 [==============================] - 1s 752ms/sample - loss: 60.4296
# Epoch 14/20
# 1/1 [==============================] - 1s 743ms/sample - loss: 60.4087
# Epoch 15/20
# 1/1 [==============================] - 1s 861ms/sample - loss: 60.3883
# Epoch 16/20
# 1/1 [==============================] - 1s 808ms/sample - loss: 60.3683
# Epoch 17/20
# 1/1 [==============================] - 1s 853ms/sample - loss: 60.3489
# Epoch 18/20
# 1/1 [==============================] - 1s 694ms/sample - loss: 60.3299
# Epoch 19/20
# 1/1 [==============================] - 1s 873ms/sample - loss: 60.3115
# Epoch 20/20
# 1/1 [==============================] - 1s 797ms/sample - loss: 60.2935
# Train on 1 samples
# Epoch 1/20
# 1/1 [==============================] - 1s 706ms/sample - loss: 60.8250
# Epoch 2/20
# 1/1 [==============================] - 1s 858ms/sample - loss: 60.8054
# Epoch 3/20
# 1/1 [==============================] - 1s 777ms/sample - loss: 60.7836
# Epoch 4/20
# 1/1 [==============================] - 1s 730ms/sample - loss: 60.7601
# Epoch 5/20
# 1/1 [==============================] - 1s 685ms/sample - loss: 60.7352
# Epoch 6/20
# 1/1 [==============================] - 1s 904ms/sample - loss: 60.7094
# Epoch 7/20
# 1/1 [==============================] - 1s 906ms/sample - loss: 60.6828
# Epoch 8/20
# 1/1 [==============================] - 1s 825ms/sample - loss: 60.6558
# Epoch 9/20
# 1/1 [==============================] - 1s 881ms/sample - loss: 60.6285
# Epoch 10/20
# 1/1 [==============================] - 1s 834ms/sample - loss: 60.6012
# Epoch 11/20
# 1/1 [==============================] - 1s 734ms/sample - loss: 60.5739
# Epoch 12/20
# 1/1 [==============================] - 1s 827ms/sample - loss: 60.5470
# Epoch 13/20
# 1/1 [==============================] - 1s 959ms/sample - loss: 60.5203
# Epoch 14/20
# 1/1 [==============================] - 1s 807ms/sample - loss: 60.4942
# Epoch 15/20
# 1/1 [==============================] - 1s 776ms/sample - loss: 60.4686
# Epoch 16/20
# 1/1 [==============================] - 1s 897ms/sample - loss: 60.4437
# Epoch 17/20
# 1/1 [==============================] - 1s 858ms/sample - loss: 60.4194
# Epoch 18/20
# 1/1 [==============================] - 1s 754ms/sample - loss: 60.3959
# Epoch 19/20
# 1/1 [==============================] - 1s 855ms/sample - loss: 60.3731
# Epoch 20/20
# 1/1 [==============================] - 1s 754ms/sample - loss: 60.3512
# Train on 1 samples
# Epoch 1/20
# 1/1 [==============================] - 1s 867ms/sample - loss: 60.4985
# Epoch 2/20
# 1/1 [==============================] - 1s 800ms/sample - loss: 60.4934
# Epoch 3/20
# 1/1 [==============================] - 1s 843ms/sample - loss: 60.4848
# Epoch 4/20
# 1/1 [==============================] - 1s 894ms/sample - loss: 60.4729
# Epoch 5/20
# 1/1 [==============================] - 1s 757ms/sample - loss: 60.4580
# Epoch 6/20
# 1/1 [==============================] - 1s 835ms/sample - loss: 60.4404
# Epoch 7/20
# 1/1 [==============================] - 1s 815ms/sample - loss: 60.4204
# Epoch 8/20
# 1/1 [==============================] - 1s 723ms/sample - loss: 60.3983
# Epoch 9/20
# 1/1 [==============================] - 1s 868ms/sample - loss: 60.3746
# Epoch 10/20
# 1/1 [==============================] - 1s 792ms/sample - loss: 60.3494
# Epoch 11/20
# 1/1 [==============================] - 1s 780ms/sample - loss: 60.3231
# Epoch 12/20
# 1/1 [==============================] - 1s 822ms/sample - loss: 60.2960
# Epoch 13/20
# 1/1 [==============================] - 1s 810ms/sample - loss: 60.2683
# Epoch 14/20
# 1/1 [==============================] - 1s 887ms/sample - loss: 60.2402
# Epoch 15/20
# 1/1 [==============================] - 1s 917ms/sample - loss: 60.2119
# Epoch 16/20
# 1/1 [==============================] - 1s 919ms/sample - loss: 60.1836
# Epoch 17/20
# 1/1 [==============================] - 1s 911ms/sample - loss: 60.1553
# Epoch 18/20
# 1/1 [==============================] - 1s 830ms/sample - loss: 60.1274
# Epoch 19/20
# 1/1 [==============================] - 1s 915ms/sample - loss: 60.0997
# Epoch 20/20
# 1/1 [==============================] - 1s 848ms/sample - loss: 60.0725
# Train on 1 samples
# Epoch 1/20
# 1/1 [==============================] - 1s 801ms/sample - loss: 60.6303
# Epoch 2/20
# 1/1 [==============================] - 1s 862ms/sample - loss: 60.6211
# Epoch 3/20
# 1/1 [==============================] - 1s 897ms/sample - loss: 60.6103
# Epoch 4/20
# 1/1 [==============================] - 1s 875ms/sample - loss: 60.5984
# Epoch 5/20
# 1/1 [==============================] - 1s 894ms/sample - loss: 60.5854
# Epoch 6/20
# 1/1 [==============================] - 1s 843ms/sample - loss: 60.5717
# Epoch 7/20
# 1/1 [==============================] - 1s 818ms/sample - loss: 60.5574
# Epoch 8/20
# 1/1 [==============================] - 1s 765ms/sample - loss: 60.5426
# Epoch 9/20
# 1/1 [==============================] - 1s 846ms/sample - loss: 60.5275
# Epoch 10/20
# 1/1 [==============================] - 1s 820ms/sample - loss: 60.5123
# Epoch 11/20
# 1/1 [==============================] - 1s 913ms/sample - loss: 60.4971
# Epoch 12/20
# 1/1 [==============================] - 1s 1s/sample - loss: 60.4818
# Epoch 13/20
# 1/1 [==============================] - 1s 765ms/sample - loss: 60.4668
# Epoch 14/20
# 1/1 [==============================] - 1s 852ms/sample - loss: 60.4518
# Epoch 15/20
# 1/1 [==============================] - 1s 812ms/sample - loss: 60.4372
# Epoch 16/20
# 1/1 [==============================] - 1s 714ms/sample - loss: 60.4228
# Epoch 17/20
# 1/1 [==============================] - 1s 852ms/sample - loss: 60.4087
# Epoch 18/20
# 1/1 [==============================] - 1s 917ms/sample - loss: 60.3950
# Epoch 19/20
# 1/1 [==============================] - 1s 805ms/sample - loss: 60.3816
# Epoch 20/20
# 1/1 [==============================] - 1s 879ms/sample - loss: 60.3686
# Train on 1 samples
# Epoch 1/20
# 1/1 [==============================] - 1s 883ms/sample - loss: 60.4399
# Epoch 2/20
# 1/1 [==============================] - 1s 864ms/sample - loss: 60.4291
# Epoch 3/20
# 1/1 [==============================] - 1s 847ms/sample - loss: 60.4181
# Epoch 4/20
# 1/1 [==============================] - 1s 950ms/sample - loss: 60.4070
# Epoch 5/20
# 1/1 [==============================] - 1s 877ms/sample - loss: 60.3957
# Epoch 6/20
# 1/1 [==============================] - 1s 861ms/sample - loss: 60.3844
# Epoch 7/20
# 1/1 [==============================] - 1s 779ms/sample - loss: 60.3731
# Epoch 8/20
# 1/1 [==============================] - 1s 841ms/sample - loss: 60.3618
# Epoch 9/20
# 1/1 [==============================] - 1s 811ms/sample - loss: 60.3505
# Epoch 10/20
# 1/1 [==============================] - 1s 1s/sample - loss: 60.3394
# Epoch 11/20
# 1/1 [==============================] - 1s 1s/sample - loss: 60.3283
# Epoch 12/20
# 1/1 [==============================] - 1s 854ms/sample - loss: 60.3175
# Epoch 13/20
# 1/1 [==============================] - 1s 1s/sample - loss: 60.3067
# Epoch 14/20
# 1/1 [==============================] - 1s 1s/sample - loss: 60.2962
# Epoch 15/20
# 1/1 [==============================] - 1s 1s/sample - loss: 60.2858
# Epoch 16/20
# 1/1 [==============================] - 1s 1s/sample - loss: 60.2757
# Epoch 17/20
# 1/1 [==============================] - 1s 1s/sample - loss: 60.2657
# Epoch 18/20
# 1/1 [==============================] - 1s 1s/sample - loss: 60.2560
# Epoch 19/20
# 1/1 [==============================] - 1s 1s/sample - loss: 60.2466
# Epoch 20/20
# Process ForkPoolWorker-960:
# Process ForkPoolWorker-957:
# Process ForkPoolWorker-958:
# Process ForkPoolWorker-959:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/cooper-cooper/.local/lib/python3.6/site-packages/multiprocess/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/cooper-cooper/.local/lib/python3.6/site-packages/multiprocess/process.py", line 258, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/home/cooper-cooper/.local/lib/python3.6/site-packages/multiprocess/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/cooper-cooper/.local/lib/python3.6/site-packages/multiprocess/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/cooper-cooper/.local/lib/python3.6/site-packages/multiprocess/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/cooper-cooper/.local/lib/python3.6/site-packages/multiprocess/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/cooper-cooper/.local/lib/python3.6/site-packages/multiprocess/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/cooper-cooper/.local/lib/python3.6/site-packages/multiprocess/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/cooper-cooper/.local/lib/python3.6/site-packages/multiprocess/pool.py", line 108, in worker
#     task = get()
#   File "/home/cooper-cooper/.local/lib/python3.6/site-packages/multiprocess/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/cooper-cooper/.local/lib/python3.6/site-packages/multiprocess/queues.py", line 338, in get
#     res = self._reader.recv_bytes()
#   File "/home/cooper-cooper/.local/lib/python3.6/site-packages/multiprocess/pool.py", line 47, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/home/cooper-cooper/.local/lib/python3.6/site-packages/multiprocess/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/cooper-cooper/.local/lib/python3.6/site-packages/multiprocess/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/cooper-cooper/.local/lib/python3.6/site-packages/multiprocess/connection.py", line 219, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/home/cooper-cooper/.local/lib/python3.6/site-packages/multiprocess/pool.py", line 47, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/home/cooper-cooper/.local/lib/python3.6/site-packages/multiprocess/pool.py", line 47, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/home/cooper-cooper/.local/lib/python3.6/site-packages/tensorflow_quantum/core/ops/batch_util.py", line 250, in _analytical_expectation_worker_func
#     params[batch_index])
#   File "/home/cooper-cooper/.local/lib/python3.6/site-packages/multiprocess/connection.py", line 410, in _recv_bytes
#     buf = self._recv(4)
#   File "/home/cooper-cooper/.local/lib/python3.6/site-packages/tensorflow_quantum/core/ops/batch_util.py", line 250, in _analytical_expectation_worker_func
#     params[batch_index])
#   File "/home/cooper-cooper/.local/lib/python3.6/site-packages/multiprocess/connection.py", line 382, in _recv
#     chunk = read(handle, remaining)
#   File "/home/cooper-cooper/.local/lib/python3.6/site-packages/cirq/sim/simulator.py", line 225, in simulate
#     initial_state)[0]
#   File "/home/cooper-cooper/.local/lib/python3.6/site-packages/tensorflow_quantum/core/ops/batch_util.py", line 250, in _analytical_expectation_worker_func
#     params[batch_index])
#   File "/home/cooper-cooper/.local/lib/python3.6/site-packages/cirq/sim/simulator.py", line 225, in simulate
#     initial_state)[0]
#   File "/home/cooper-cooper/.local/lib/python3.6/site-packages/cirq/sim/simulator.py", line 300, in simulate_sweep
#     program, param_resolver, qubit_order, initial_state)
#   File "/home/cooper-cooper/.local/lib/python3.6/site-packages/cirq/sim/simulator.py", line 300, in simulate_sweep
#     program, param_resolver, qubit_order, initial_state)
#   File "/home/cooper-cooper/.local/lib/python3.6/site-packages/cirq/sim/simulator.py", line 225, in simulate
#     initial_state)[0]
#   File "/home/cooper-cooper/.local/lib/python3.6/site-packages/cirq/sim/simulator.py", line 342, in simulate_moment_steps
#     initial_state)
#   File "/home/cooper-cooper/.local/lib/python3.6/site-packages/cirq/sim/simulator.py", line 342, in simulate_moment_steps
#     initial_state)
#   File "/home/cooper-cooper/.local/lib/python3.6/site-packages/cirq/sim/simulator.py", line 300, in simulate_sweep
#     program, param_resolver, qubit_order, initial_state)
# KeyboardInterrupt
#   File "/home/cooper-cooper/.local/lib/python3.6/site-packages/cirq/sim/density_matrix_simulator.py", line 224, in _simulator_iterator
#     resolved_circuit = protocols.resolve_parameters(circuit, param_resolver)
#   File "/home/cooper-cooper/.local/lib/python3.6/site-packages/cirq/sim/simulator.py", line 342, in simulate_moment_steps
#     initial_state)
#   File "/home/cooper-cooper/.local/lib/python3.6/site-packages/cirq/sim/density_matrix_simulator.py", line 224, in _simulator_iterator
#     resolved_circuit = protocols.resolve_parameters(circuit, param_resolver)
#   File "/home/cooper-cooper/.local/lib/python3.6/site-packages/cirq/protocols/resolve_parameters.py", line 100, in resolve_parameters
#     result = NotImplemented if getter is None else getter(param_resolver)
#   File "/home/cooper-cooper/.local/lib/python3.6/site-packages/cirq/protocols/resolve_parameters.py", line 100, in resolve_parameters
#     result = NotImplemented if getter is None else getter(param_resolver)
#   File "/home/cooper-cooper/.local/lib/python3.6/site-packages/cirq/circuits/circuit.py", line 1694, in _resolve_parameters_
#     param_resolver)
#   File "/home/cooper-cooper/.local/lib/python3.6/site-packages/cirq/sim/density_matrix_simulator.py", line 224, in _simulator_iterator
#     resolved_circuit = protocols.resolve_parameters(circuit, param_resolver)
#   File "/home/cooper-cooper/.local/lib/python3.6/site-packages/cirq/protocols/resolve_parameters.py", line 100, in resolve_parameters
#     result = NotImplemented if getter is None else getter(param_resolver)
#   File "/home/cooper-cooper/.local/lib/python3.6/site-packages/cirq/circuits/circuit.py", line 1694, in _resolve_parameters_
#     param_resolver)
#   File "/home/cooper-cooper/.local/lib/python3.6/site-packages/cirq/circuits/circuit.py", line 1694, in _resolve_parameters_
#     param_resolver)
#   File "/home/cooper-cooper/.local/lib/python3.6/site-packages/cirq/circuits/circuit.py", line 1803, in _resolve_operations
#     op, param_resolver))
#   File "/home/cooper-cooper/.local/lib/python3.6/site-packages/cirq/circuits/circuit.py", line 1803, in _resolve_operations
#     op, param_resolver))
#   File "/home/cooper-cooper/.local/lib/python3.6/site-packages/cirq/circuits/circuit.py", line 1803, in _resolve_operations
#     op, param_resolver))
#   File "/home/cooper-cooper/.local/lib/python3.6/site-packages/cirq/protocols/resolve_parameters.py", line 100, in resolve_parameters
#     result = NotImplemented if getter is None else getter(param_resolver)
#   File "/home/cooper-cooper/.local/lib/python3.6/site-packages/cirq/protocols/resolve_parameters.py", line 100, in resolve_parameters
#     result = NotImplemented if getter is None else getter(param_resolver)
#   File "/home/cooper-cooper/.local/lib/python3.6/site-packages/cirq/ops/gate_operation.py", line 151, in _resolve_parameters_
#     resolved_gate = protocols.resolve_parameters(self.gate, resolver)
#   File "/home/cooper-cooper/.local/lib/python3.6/site-packages/cirq/protocols/resolve_parameters.py", line 100, in resolve_parameters
#     result = NotImplemented if getter is None else getter(param_resolver)
#   File "/home/cooper-cooper/.local/lib/python3.6/site-packages/cirq/ops/gate_operation.py", line 151, in _resolve_parameters_
#     resolved_gate = protocols.resolve_parameters(self.gate, resolver)
#   File "/home/cooper-cooper/.local/lib/python3.6/site-packages/cirq/protocols/resolve_parameters.py", line 100, in resolve_parameters
#     result = NotImplemented if getter is None else getter(param_resolver)
#   File "/home/cooper-cooper/.local/lib/python3.6/site-packages/cirq/protocols/resolve_parameters.py", line 100, in resolve_parameters
#     result = NotImplemented if getter is None else getter(param_resolver)
#   File "/home/cooper-cooper/.local/lib/python3.6/site-packages/cirq/ops/gate_operation.py", line 151, in _resolve_parameters_
#     resolved_gate = protocols.resolve_parameters(self.gate, resolver)
#   File "/home/cooper-cooper/.local/lib/python3.6/site-packages/cirq/ops/eigen_gate.py", line 348, in _resolve_parameters_
#     exponent=param_resolver.value_of(self._exponent))
#   File "/home/cooper-cooper/.local/lib/python3.6/site-packages/cirq/ops/eigen_gate.py", line 348, in _resolve_parameters_
#     exponent=param_resolver.value_of(self._exponent))
#   File "/home/cooper-cooper/.local/lib/python3.6/site-packages/cirq/protocols/resolve_parameters.py", line 100, in resolve_parameters
#     result = NotImplemented if getter is None else getter(param_resolver)
#   File "/home/cooper-cooper/.local/lib/python3.6/site-packages/cirq/study/resolver.py", line 121, in value_of
#     v = value.subs(self.param_dict)
#   File "/home/cooper-cooper/.local/lib/python3.6/site-packages/cirq/study/resolver.py", line 121, in value_of
#     v = value.subs(self.param_dict)
#   File "/home/cooper-cooper/.local/lib/python3.6/site-packages/sympy/core/basic.py", line 997, in subs
#     rv = rv._subs(old, new, **kwargs)
#   File "/home/cooper-cooper/.local/lib/python3.6/site-packages/cirq/ops/eigen_gate.py", line 348, in _resolve_parameters_
#     exponent=param_resolver.value_of(self._exponent))
#   File "/home/cooper-cooper/.local/lib/python3.6/site-packages/cirq/study/resolver.py", line 121, in value_of
#     v = value.subs(self.param_dict)
#   File "/home/cooper-cooper/.local/lib/python3.6/site-packages/sympy/core/cache.py", line 94, in wrapper
#     retval = cfunc(*args, **kwargs)
#   File "/home/cooper-cooper/.local/lib/python3.6/site-packages/sympy/core/basic.py", line 976, in subs
#     key=default_sort_key)
# KeyboardInterrupt
#   File "/home/cooper-cooper/.local/lib/python3.6/site-packages/sympy/core/basic.py", line 1111, in _subs
#     rv = fallback(self, old, new)
#   File "/home/cooper-cooper/.local/lib/python3.6/site-packages/sympy/core/basic.py", line 949, in subs
#     for _ in s]
#   File "/home/cooper-cooper/.local/lib/python3.6/site-packages/sympy/core/basic.py", line 949, in <listcomp>
#     for _ in s]
#   File "/home/cooper-cooper/.local/lib/python3.6/site-packages/sympy/core/sympify.py", line 268, in sympify
#     if a in sympy_classes:
# KeyboardInterrupt
#   File "/home/cooper-cooper/.local/lib/python3.6/site-packages/sympy/core/basic.py", line 1084, in fallback
#     if not _aresame(arg, args[i]):
#   File "/home/cooper-cooper/.local/lib/python3.6/site-packages/sympy/core/basic.py", line 1855, in _aresame
#     if i != j or type(i) != type(j):
#   File "/home/cooper-cooper/.local/lib/python3.6/site-packages/sympy/core/numbers.py", line 1273, in __ne__
#     return not self == other
#   File "/home/cooper-cooper/.local/lib/python3.6/site-packages/sympy/core/numbers.py", line 1261, in __eq__
#     return bool(mlib.mpf_eq(self._mpf_, other._mpf_))
#   File "/home/cooper-cooper/.local/lib/python3.6/site-packages/mpmath/libmp/libmpf.py", line 540, in mpf_eq
#     if not s[1] or not t[1]:
# KeyboardInterrupt

# %%
np.squeeze(tf.math.reduce_sum(model.predict(tfqcircuit), axis=-1))

# %%
circuit_input = tf.keras.Input(shape=(), dtype=tf.string)
output = tfq.layers.Expectation()(
circuit_input,
symbol_names=symbols,
operators=tfq.convert_to_tensor([observable]),
initializer=tf.keras.initializers.RandomNormal()) #we may change this!!!

model = tf.keras.Model(inputs=circuit_input, outputs=output)
adam = tf.keras.optimizers.Adam(learning_rate=0.01)
model.compile(optimizer=adam, loss='mse')
tfqcircuit = tfq.convert_to_tensor([circuit])
qoutput = tf.ones((1, 1))*-2.*n_qubits
model.fit(x=tfqcircuit, y=qoutput, batch_size=1, epochs=250, verbose=1, callbacks=[tf.keras.callbacks.EarlyStopping(monitor='loss', patience=5)])

# %%
np.squeeze(tf.math.reduce_sum(model.predict(tfqcircuit), axis=-1))
