# %%
import numpy as np
import sympy
import cirq
import tensorflow as tf
import tensorflow_quantum as tfq

class CirqSmartSolver:
    def __init__(self, n_qubits=3, observable_name=None, ground_state_energy=None, qlr=0.01, qepochs=100):

        """
        observable_name:: specifies the hamiltonian; can be either string (if in templates, see load_observable function, a list
        or numpy array.

        target_reward:: minus the ground energy (or estimation), used as label for variational optimization.
        """

        self.name = "CirqSolver"
        self.n_qubits = n_qubits
        self.qubits = cirq.GridQubit.rect(1, n_qubits)
        self.observable_name = observable_name

        # Value to use as label for continuous optimization; this appears in variational model
        if ground_state_energy is None:
            self.ground_state_energy = self.n_qubits  # mostly for the ising high transv fields.
        else:
            self.ground_state_energy = ground_state_energy

        self.observable = self.load_observable(observable_name) #Ising hamiltonian with list of pauli_gates
        self.qlr = qlr
        self.qepochs=qepochs
        # Indexed cnots total number n!/(n-2)! = n*(n-1) (if all connections are allowed)
        self.indexed_cnots = {}
        count = 0
        for control in range(self.n_qubits):
            for target in range(self.n_qubits):
                if control != target:
                    self.indexed_cnots[str(count)] = [control, target]
                    count += 1
        self.number_of_cnots = len(self.indexed_cnots)
        #int(np.math.factorial(self.n_qubits)/np.math.factorial(self.n_qubits -2))

        # Create one_hot a+lphabet
        self.alphabet_gates = [cirq.CNOT, cirq.ry, cirq.rx(-np.pi/2), cirq.I]
        self.alphabet = []

        alphabet_length = self.number_of_cnots + (len(self.alphabet_gates)-1)*self.n_qubits
        for ind, k in enumerate(range(self.number_of_cnots + (len(self.alphabet_gates)-1)*self.n_qubits)): #one hot encoding
            one_hot_gate = [-1]*alphabet_length
            one_hot_gate[ind] = 1
            self.alphabet.append(one_hot_gate)

    def load_observable(self, obs,g=1, J=0):
        """
        obs can either be a string, a list with cirq's gates or a matrix (array)
        """
        if obs == "Ising_":
            observable = [g*cirq.X.on(q) for q in self.qubits] # -J \sum_{i} Z_i Z_{i+1} - g \sum_i X_i    when g>>J
            for q in range(len(self.qubits)):
                observable.append(J*cirq.Z.on(self.qubits[q])*cirq.Z.on(self.qubits[(q+1)%len(self.qubits)]))
        else:
            print("check previous versions to load other observables.")
        return observable

    def append_to_circuit(self, one_hot_gate, circuit, params):
        """
        appends to circuit the one_hot_gate;
        and if one_hot_gate it implies a rotation,
        appends to params a symbol"""

        for ind,inst in enumerate(one_hot_gate):
            if inst == 1:  # this is faster than numpy.where
                if ind < self.number_of_cnots:
                    control, target = self.indexed_cnots[str(ind)]
                    circuit.append(self.alphabet_gates[0].on(self.qubits[control], self.qubits[target]))
                    return circuit, params
                elif self.number_of_cnots <= ind < self.number_of_cnots + self.n_qubits:
                    new_param = "th_"+str(len(params))
                    params.append(new_param)
                    circuit.append(self.alphabet_gates[1](sympy.Symbol(new_param)).on(self.qubits[int(ind%self.n_qubits)]))
                    return circuit, params
                elif self.number_of_cnots + self.n_qubits <= ind < self.number_of_cnots + 2*self.n_qubits:
                    circuit.append(self.alphabet_gates[2].on(self.qubits[int(ind%self.n_qubits)]))
                    return circuit, params
                elif self.number_of_cnots + 2*self.n_qubits <= ind < self.number_of_cnots+3*self.number_of_cnots:
                    circuit.append(self.alphabet_gates[3].on(self.qubits[int(ind%self.n_qubits)]))
                    return circuit, params
                else:
                    print("doing nothing! even not identity! careful")
                    return circuit, params
                
                
    def TFQ_model(self, symbols):
        circuit_input = tf.keras.Input(shape=(), dtype=tf.string)
        output = tfq.layers.Expectation()(
                circuit_input,
                symbol_names=symbols,
                operators=tfq.convert_to_tensor([self.observable]),
                initializer=tf.keras.initializers.RandomNormal()) #this is not strictly necessary.
        model = tf.keras.Model(inputs=circuit_input, outputs=output)
        adam = tf.keras.optimizers.Adam(learning_rate=self.qlr)
        model.compile(optimizer=adam, loss='mse')
        return model
        
    
    def run_circuit(self, gates_index, sim_q_state=False):
        """
        takes as input vector with actions described as integer (given by RL agent),
        and outputsthe energy of that circuit (w.r.t self.observable)
            """
        circuit, symbols = [], []
        for k in gates_index:
            circuit, symbols = self.append_to_circuit(self.alphabet[k],circuit,symbols)
        tfqcircuit = tfq.convert_to_tensor([cirq.Circuit(circuit)])
        if len(symbols) == 0:
            expval = tfq.layers.Expectation()(
                                            tfqcircuit,
                                            operators=tfq.convert_to_tensor([self.observable]))
            energy = np.float32(np.squeeze(tf.math.reduce_sum(expval, axis=-1, keepdims=True)))
        else:
            model = self.TFQ_model(symbols)
            qoutput = tf.ones((1, 1))*self.ground_state_energy
            model.fit(x=tfqcircuit, y=qoutput, batch_size=1, epochs=self.qepochs, verbose=1)
            energy = np.squeeze(tf.math.reduce_sum(model.predict(tfqcircuit), axis=-1))
            #energy = np.sum(energies)
        return energy

# %%
circuit, symbols = [], []
for k in gates_index:
    circuit, symbols = solver.append_to_circuit(solver.alphabet[k],circuit,symbols)

# %%
cirq.Circuit(circuit)
# Out:
# (0, 0): ───Ry(th_0)───
#
# (0, 1): ───Ry(th_1)───
#
# (0, 2): ───Ry(th_2)───

# %%
cirq.Circuit(solver.observable)
# Out:
# (0, 0): ───X───0j*Z((0, 0))*Z((0, 1))────────────────────────────0j*Z((0, 0))*Z((0, 2))───
#                │                                                 │
# (0, 1): ───X───#2───────────────────────0j*Z((0, 1))*Z((0, 2))───┼────────────────────────
#                                         │                        │
# (0, 2): ───X────────────────────────────#2───────────────────────#2───────────────────────

# %%
solver = CirqSmartSolver(n_qubits=3, observable_name="Ising_", qlr=0.1,qepochs=250, ground_state_energy=4)
gates_index = solver.number_of_cnots + np.arange(solver.n_qubits)
solver.run_circuit(gates_index)
# Out:
# Train on 1 samples
# Epoch 1/250
# 1/1 [==============================] - 1s 623ms/sample - loss: 15.8465
# Epoch 2/250
# 1/1 [==============================] - 0s 4ms/sample - loss: 15.4572
# Epoch 3/250
# 1/1 [==============================] - 0s 3ms/sample - loss: 15.0834
# Epoch 4/250
# 1/1 [==============================] - 0s 3ms/sample - loss: 14.7285
# Epoch 5/250
# 1/1 [==============================] - 0s 4ms/sample - loss: 14.3958
# Epoch 6/250
# 1/1 [==============================] - 0s 5ms/sample - loss: 14.0878
# Epoch 7/250
# 1/1 [==============================] - 0s 2ms/sample - loss: 13.8066
# Epoch 8/250
# 1/1 [==============================] - 0s 5ms/sample - loss: 13.5536
# Epoch 9/250
# 1/1 [==============================] - 0s 7ms/sample - loss: 13.3297
# Epoch 10/250
# 1/1 [==============================] - 0s 3ms/sample - loss: 13.1352
# Epoch 11/250
# 1/1 [==============================] - 0s 3ms/sample - loss: 12.9699
# Epoch 12/250
# 1/1 [==============================] - 0s 4ms/sample - loss: 12.8329
# Epoch 13/250
# 1/1 [==============================] - 0s 3ms/sample - loss: 12.7228
# Epoch 14/250
# 1/1 [==============================] - 0s 7ms/sample - loss: 12.6379
# Epoch 15/250
# 1/1 [==============================] - 0s 8ms/sample - loss: 12.5760
# Epoch 16/250
# 1/1 [==============================] - 0s 5ms/sample - loss: 12.5344
# Epoch 17/250
# 1/1 [==============================] - 0s 5ms/sample - loss: 12.5104
# Epoch 18/250
# 1/1 [==============================] - 0s 5ms/sample - loss: 12.5010
# Epoch 19/250
# 1/1 [==============================] - 0s 2ms/sample - loss: 12.5031
# Epoch 20/250
# 1/1 [==============================] - 0s 3ms/sample - loss: 12.5136
# Epoch 21/250
# 1/1 [==============================] - 0s 3ms/sample - loss: 12.5297
# Epoch 22/250
# 1/1 [==============================] - 0s 3ms/sample - loss: 12.5487
# Epoch 23/250
# 1/1 [==============================] - 0s 3ms/sample - loss: 12.5683
# Epoch 24/250
# 1/1 [==============================] - 0s 3ms/sample - loss: 12.5867
# Epoch 25/250
# 1/1 [==============================] - 0s 3ms/sample - loss: 12.6023
# Epoch 26/250
# 1/1 [==============================] - 0s 3ms/sample - loss: 12.6143
# Epoch 27/250
# 1/1 [==============================] - 0s 8ms/sample - loss: 12.6219
# Epoch 28/250
# 1/1 [==============================] - 0s 4ms/sample - loss: 12.6251
# Epoch 29/250
# 1/1 [==============================] - 0s 3ms/sample - loss: 12.6240
# Epoch 30/250
# 1/1 [==============================] - 0s 9ms/sample - loss: 12.6190
# Epoch 31/250
# 1/1 [==============================] - 0s 4ms/sample - loss: 12.6108
# Epoch 32/250
# 1/1 [==============================] - 0s 5ms/sample - loss: 12.6001
# Epoch 33/250
# 1/1 [==============================] - 0s 3ms/sample - loss: 12.5877
# Epoch 34/250
# 1/1 [==============================] - 0s 8ms/sample - loss: 12.5744
# Epoch 35/250
# 1/1 [==============================] - 0s 3ms/sample - loss: 12.5609
# Epoch 36/250
# 1/1 [==============================] - 0s 4ms/sample - loss: 12.5480
# Epoch 37/250
# 1/1 [==============================] - 0s 3ms/sample - loss: 12.5361
# Epoch 38/250
# 1/1 [==============================] - 0s 6ms/sample - loss: 12.5257
# Epoch 39/250
# 1/1 [==============================] - 0s 7ms/sample - loss: 12.5170
# Epoch 40/250
# 1/1 [==============================] - 0s 3ms/sample - loss: 12.5102
# Epoch 41/250
# 1/1 [==============================] - 0s 3ms/sample - loss: 12.5053
# Epoch 42/250
# 1/1 [==============================] - 0s 9ms/sample - loss: 12.5021
# Epoch 43/250
# 1/1 [==============================] - 0s 6ms/sample - loss: 12.5005
# Epoch 44/250
# 1/1 [==============================] - 0s 3ms/sample - loss: 12.5002
# Epoch 45/250
# 1/1 [==============================] - 0s 3ms/sample - loss: 12.5009
# Epoch 46/250
# 1/1 [==============================] - 0s 4ms/sample - loss: 12.5023
# Epoch 47/250
# 1/1 [==============================] - 0s 4ms/sample - loss: 12.5041
# Epoch 48/250
# 1/1 [==============================] - 0s 4ms/sample - loss: 12.5060
# Epoch 49/250
# 1/1 [==============================] - 0s 4ms/sample - loss: 12.5078
# Epoch 50/250
# 1/1 [==============================] - 0s 11ms/sample - loss: 12.5093
# Epoch 51/250
# 1/1 [==============================] - 0s 3ms/sample - loss: 12.5104
# Epoch 52/250
# 1/1 [==============================] - 0s 2ms/sample - loss: 12.5110
# Epoch 53/250
# 1/1 [==============================] - 0s 3ms/sample - loss: 12.5111
# Epoch 54/250
# 1/1 [==============================] - 0s 3ms/sample - loss: 12.5107
# Epoch 55/250
# 1/1 [==============================] - 0s 4ms/sample - loss: 12.5100
# Epoch 56/250
# 1/1 [==============================] - 0s 8ms/sample - loss: 12.5090
# Epoch 57/250
# 1/1 [==============================] - 0s 12ms/sample - loss: 12.5077
# Epoch 58/250
# 1/1 [==============================] - 0s 4ms/sample - loss: 12.5064
# Epoch 59/250
# 1/1 [==============================] - 0s 4ms/sample - loss: 12.5050
# Epoch 60/250
# 1/1 [==============================] - 0s 9ms/sample - loss: 12.5037
# Epoch 61/250
# 1/1 [==============================] - 0s 3ms/sample - loss: 12.5026
# Epoch 62/250
# 1/1 [==============================] - 0s 5ms/sample - loss: 12.5017
# Epoch 63/250
# 1/1 [==============================] - 0s 10ms/sample - loss: 12.5009
# Epoch 64/250
# 1/1 [==============================] - 0s 4ms/sample - loss: 12.5004
# Epoch 65/250
# 1/1 [==============================] - 0s 10ms/sample - loss: 12.5002
# Epoch 66/250
# 1/1 [==============================] - 0s 3ms/sample - loss: 12.5000
# Epoch 67/250
# 1/1 [==============================] - 0s 4ms/sample - loss: 12.5001
# Epoch 68/250
# 1/1 [==============================] - 0s 3ms/sample - loss: 12.5002
# Epoch 69/250
# 1/1 [==============================] - 0s 5ms/sample - loss: 12.5004
# Epoch 70/250
# 1/1 [==============================] - 0s 4ms/sample - loss: 12.5006
# Epoch 71/250
# 1/1 [==============================] - 0s 4ms/sample - loss: 12.5008
# Epoch 72/250
# 1/1 [==============================] - 0s 6ms/sample - loss: 12.5010
# Epoch 73/250
# 1/1 [==============================] - 0s 6ms/sample - loss: 12.5011
# Epoch 74/250
# 1/1 [==============================] - 0s 4ms/sample - loss: 12.5012
# Epoch 75/250
# 1/1 [==============================] - 0s 5ms/sample - loss: 12.5012
# Epoch 76/250
# 1/1 [==============================] - 0s 4ms/sample - loss: 12.5011
# Epoch 77/250
# 1/1 [==============================] - 0s 6ms/sample - loss: 12.5010
# Epoch 78/250
# 1/1 [==============================] - 0s 5ms/sample - loss: 12.5009
# Epoch 79/250
# 1/1 [==============================] - 0s 5ms/sample - loss: 12.5007
# Epoch 80/250
# 1/1 [==============================] - 0s 4ms/sample - loss: 12.5005
# Epoch 81/250
# 1/1 [==============================] - 0s 5ms/sample - loss: 12.5004
# Epoch 82/250
# 1/1 [==============================] - 0s 6ms/sample - loss: 12.5003
# Epoch 83/250
# 1/1 [==============================] - 0s 4ms/sample - loss: 12.5002
# Epoch 84/250
# 1/1 [==============================] - 0s 5ms/sample - loss: 12.5001
# Epoch 85/250
# 1/1 [==============================] - 0s 3ms/sample - loss: 12.5000
# Epoch 86/250
# 1/1 [==============================] - 0s 4ms/sample - loss: 12.5000
# Epoch 87/250
# 1/1 [==============================] - 0s 5ms/sample - loss: 12.5000
# Epoch 88/250
# 1/1 [==============================] - 0s 4ms/sample - loss: 12.5000
# Epoch 89/250
# 1/1 [==============================] - 0s 6ms/sample - loss: 12.5001
# Epoch 90/250
# 1/1 [==============================] - 0s 5ms/sample - loss: 12.5001
# Epoch 91/250
# 1/1 [==============================] - 0s 5ms/sample - loss: 12.5001
# Epoch 92/250
# 1/1 [==============================] - 0s 4ms/sample - loss: 12.5001
# Epoch 93/250
# 1/1 [==============================] - 0s 3ms/sample - loss: 12.5002
# Epoch 94/250
# 1/1 [==============================] - 0s 13ms/sample - loss: 12.5002
# Epoch 95/250
# 1/1 [==============================] - 0s 7ms/sample - loss: 12.5002
# Epoch 96/250
# 1/1 [==============================] - 0s 5ms/sample - loss: 12.5002
# Epoch 97/250
# 1/1 [==============================] - 0s 4ms/sample - loss: 12.5001
# Epoch 98/250
# 1/1 [==============================] - 0s 6ms/sample - loss: 12.5001
# Epoch 99/250
# 1/1 [==============================] - 0s 7ms/sample - loss: 12.5001
# Epoch 100/250
# 1/1 [==============================] - 0s 5ms/sample - loss: 12.5001
# Epoch 101/250
# 1/1 [==============================] - 0s 4ms/sample - loss: 12.5001
# Epoch 102/250
# 1/1 [==============================] - 0s 4ms/sample - loss: 12.5000
# Epoch 103/250
# 1/1 [==============================] - 0s 5ms/sample - loss: 12.5000
# Epoch 104/250
# 1/1 [==============================] - 0s 3ms/sample - loss: 12.5000
# Epoch 105/250
# 1/1 [==============================] - 0s 7ms/sample - loss: 12.5000
# Epoch 106/250
# 1/1 [==============================] - 0s 4ms/sample - loss: 12.5000
# Epoch 107/250
# 1/1 [==============================] - 0s 7ms/sample - loss: 12.5000
# Epoch 108/250
# 1/1 [==============================] - 0s 6ms/sample - loss: 12.5000
# Epoch 109/250
# 1/1 [==============================] - 0s 3ms/sample - loss: 12.5000
# Epoch 110/250
# 1/1 [==============================] - 0s 3ms/sample - loss: 12.5000
# Epoch 111/250
# 1/1 [==============================] - 0s 4ms/sample - loss: 12.5000
# Epoch 112/250
# 1/1 [==============================] - 0s 3ms/sample - loss: 12.5000
# Epoch 113/250
# 1/1 [==============================] - 0s 3ms/sample - loss: 12.5000
# Epoch 114/250
# 1/1 [==============================] - 0s 3ms/sample - loss: 12.5000
# Epoch 115/250
# 1/1 [==============================] - 0s 4ms/sample - loss: 12.5000
# Epoch 116/250
# 1/1 [==============================] - 0s 4ms/sample - loss: 12.5000
# Epoch 117/250
# 1/1 [==============================] - 0s 4ms/sample - loss: 12.5000
# Epoch 118/250
# 1/1 [==============================] - 0s 4ms/sample - loss: 12.5000
# Epoch 119/250
# 1/1 [==============================] - 0s 3ms/sample - loss: 12.5000
# Epoch 120/250
# 1/1 [==============================] - 0s 4ms/sample - loss: 12.5000
# Epoch 121/250
# 1/1 [==============================] - 0s 5ms/sample - loss: 12.5000
# Epoch 122/250
# 1/1 [==============================] - 0s 4ms/sample - loss: 12.5000
# Epoch 123/250
# 1/1 [==============================] - 0s 4ms/sample - loss: 12.5000
# Epoch 124/250
# 1/1 [==============================] - 0s 4ms/sample - loss: 12.5000
# Epoch 125/250
# 1/1 [==============================] - 0s 3ms/sample - loss: 12.5000
# Epoch 126/250
# 1/1 [==============================] - 0s 5ms/sample - loss: 12.5000
# Epoch 127/250
# 1/1 [==============================] - 0s 4ms/sample - loss: 12.5000
# Epoch 128/250
# 1/1 [==============================] - 0s 5ms/sample - loss: 12.5000
# Epoch 129/250
# 1/1 [==============================] - 0s 4ms/sample - loss: 12.5000
# Epoch 130/250
# 1/1 [==============================] - 0s 4ms/sample - loss: 12.5000
# Epoch 131/250
# 1/1 [==============================] - 0s 4ms/sample - loss: 12.5000
# Epoch 132/250
# 1/1 [==============================] - 0s 4ms/sample - loss: 12.5000
# Epoch 133/250
# 1/1 [==============================] - 0s 3ms/sample - loss: 12.5000
# Epoch 134/250
# 1/1 [==============================] - 0s 3ms/sample - loss: 12.5000
# Epoch 135/250
# 1/1 [==============================] - 0s 3ms/sample - loss: 12.5000
# Epoch 136/250
# 1/1 [==============================] - 0s 2ms/sample - loss: 12.5000
# Epoch 137/250
# 1/1 [==============================] - 0s 2ms/sample - loss: 12.5000
# Epoch 138/250
# 1/1 [==============================] - 0s 4ms/sample - loss: 12.5000
# Epoch 139/250
# 1/1 [==============================] - 0s 4ms/sample - loss: 12.5000
# Epoch 140/250
# 1/1 [==============================] - 0s 3ms/sample - loss: 12.5000
# Epoch 141/250
# 1/1 [==============================] - 0s 4ms/sample - loss: 12.5000
# Epoch 142/250
# 1/1 [==============================] - 0s 4ms/sample - loss: 12.5000
# Epoch 143/250
# 1/1 [==============================] - 0s 3ms/sample - loss: 12.5000
# Epoch 144/250
# 1/1 [==============================] - 0s 3ms/sample - loss: 12.5000
# Epoch 145/250
# 1/1 [==============================] - 0s 2ms/sample - loss: 12.5000
# Epoch 146/250
# 1/1 [==============================] - 0s 3ms/sample - loss: 12.5000
# Epoch 147/250
# 1/1 [==============================] - 0s 3ms/sample - loss: 12.5000
# Epoch 148/250
# 1/1 [==============================] - 0s 2ms/sample - loss: 12.5000
# Epoch 149/250
# 1/1 [==============================] - 0s 6ms/sample - loss: 12.5000
# Epoch 150/250
# 1/1 [==============================] - 0s 5ms/sample - loss: 12.5000
# Epoch 151/250
# 1/1 [==============================] - 0s 3ms/sample - loss: 12.5000
# Epoch 152/250
# 1/1 [==============================] - 0s 5ms/sample - loss: 12.5000
# Epoch 153/250
# 1/1 [==============================] - 0s 5ms/sample - loss: 12.5000
# Epoch 154/250
# 1/1 [==============================] - 0s 4ms/sample - loss: 12.5000
# Epoch 155/250
# 1/1 [==============================] - 0s 3ms/sample - loss: 12.5000
# Epoch 156/250
# 1/1 [==============================] - 0s 3ms/sample - loss: 12.5000
# Epoch 157/250
# 1/1 [==============================] - 0s 3ms/sample - loss: 12.5000
# Epoch 158/250
# 1/1 [==============================] - 0s 3ms/sample - loss: 12.5000
# Epoch 159/250
# 1/1 [==============================] - 0s 3ms/sample - loss: 12.5000
# Epoch 160/250
# 1/1 [==============================] - 0s 4ms/sample - loss: 12.5000
# Epoch 161/250
# 1/1 [==============================] - 0s 4ms/sample - loss: 12.5000
# Epoch 162/250
# 1/1 [==============================] - 0s 5ms/sample - loss: 12.5000
# Epoch 163/250
# 1/1 [==============================] - 0s 3ms/sample - loss: 12.5000
# Epoch 164/250
# 1/1 [==============================] - 0s 5ms/sample - loss: 12.5000
# Epoch 165/250
# 1/1 [==============================] - 0s 6ms/sample - loss: 12.5000
# Epoch 166/250
# 1/1 [==============================] - 0s 5ms/sample - loss: 12.5000
# Epoch 167/250
# 1/1 [==============================] - 0s 5ms/sample - loss: 12.5000
# Epoch 168/250
# 1/1 [==============================] - 0s 5ms/sample - loss: 12.5000
# Epoch 169/250
# 1/1 [==============================] - 0s 7ms/sample - loss: 12.5000
# Epoch 170/250
# 1/1 [==============================] - 0s 7ms/sample - loss: 12.5000
# Epoch 171/250
# 1/1 [==============================] - 0s 4ms/sample - loss: 12.5000
# Epoch 172/250
# 1/1 [==============================] - 0s 4ms/sample - loss: 12.5000
# Epoch 173/250
# 1/1 [==============================] - 0s 5ms/sample - loss: 12.5000
# Epoch 174/250
# 1/1 [==============================] - 0s 5ms/sample - loss: 12.5000
# Epoch 175/250
# 1/1 [==============================] - 0s 4ms/sample - loss: 12.5000
# Epoch 176/250
# 1/1 [==============================] - 0s 5ms/sample - loss: 12.5000
# Epoch 177/250
# 1/1 [==============================] - 0s 4ms/sample - loss: 12.5000
# Epoch 178/250
# 1/1 [==============================] - 0s 4ms/sample - loss: 12.5000
# Epoch 179/250
# 1/1 [==============================] - 0s 4ms/sample - loss: 12.5000
# Epoch 180/250
# 1/1 [==============================] - 0s 5ms/sample - loss: 12.5000
# Epoch 181/250
# 1/1 [==============================] - 0s 4ms/sample - loss: 12.5000
# Epoch 182/250
# 1/1 [==============================] - 0s 5ms/sample - loss: 12.5000
# Epoch 183/250
# 1/1 [==============================] - 0s 4ms/sample - loss: 12.5000
# Epoch 184/250
# 1/1 [==============================] - 0s 5ms/sample - loss: 12.5000
# Epoch 185/250
# 1/1 [==============================] - 0s 5ms/sample - loss: 12.5000
# Epoch 186/250
# 1/1 [==============================] - 0s 5ms/sample - loss: 12.5000
# Epoch 187/250
# 1/1 [==============================] - 0s 3ms/sample - loss: 12.5000
# Epoch 188/250
# 1/1 [==============================] - 0s 5ms/sample - loss: 12.5000
# Epoch 189/250
# 1/1 [==============================] - 0s 7ms/sample - loss: 12.5000
# Epoch 190/250
# 1/1 [==============================] - 0s 3ms/sample - loss: 12.5000
# Epoch 191/250
# 1/1 [==============================] - 0s 5ms/sample - loss: 12.5000
# Epoch 192/250
# 1/1 [==============================] - 0s 6ms/sample - loss: 12.5000
# Epoch 193/250
# 1/1 [==============================] - 0s 4ms/sample - loss: 12.5000
# Epoch 194/250
# 1/1 [==============================] - 0s 6ms/sample - loss: 12.5000
# Epoch 195/250
# 1/1 [==============================] - 0s 4ms/sample - loss: 12.5000
# Epoch 196/250
# 1/1 [==============================] - 0s 4ms/sample - loss: 12.5000
# Epoch 197/250
# 1/1 [==============================] - 0s 3ms/sample - loss: 12.5000
# Epoch 198/250
# 1/1 [==============================] - 0s 4ms/sample - loss: 12.5000
# Epoch 199/250
# 1/1 [==============================] - 0s 4ms/sample - loss: 12.5000
# Epoch 200/250
# 1/1 [==============================] - 0s 4ms/sample - loss: 12.5000
# Epoch 201/250
# 1/1 [==============================] - 0s 5ms/sample - loss: 12.5000
# Epoch 202/250
# 1/1 [==============================] - 0s 4ms/sample - loss: 12.5000
# Epoch 203/250
# 1/1 [==============================] - 0s 4ms/sample - loss: 12.5000
# Epoch 204/250
# 1/1 [==============================] - 0s 3ms/sample - loss: 12.5000
# Epoch 205/250
# 1/1 [==============================] - 0s 3ms/sample - loss: 12.5000
# Epoch 206/250
# 1/1 [==============================] - 0s 5ms/sample - loss: 12.5000
# Epoch 207/250
# 1/1 [==============================] - 0s 4ms/sample - loss: 12.5000
# Epoch 208/250
# 1/1 [==============================] - 0s 4ms/sample - loss: 12.5000
# Epoch 209/250
# 1/1 [==============================] - 0s 5ms/sample - loss: 12.5000
# Epoch 210/250
# 1/1 [==============================] - 0s 4ms/sample - loss: 12.5000
# Epoch 211/250
# 1/1 [==============================] - 0s 4ms/sample - loss: 12.5000
# Epoch 212/250
# 1/1 [==============================] - 0s 3ms/sample - loss: 12.5000
# Epoch 213/250
# 1/1 [==============================] - 0s 3ms/sample - loss: 12.5000
# Epoch 214/250
# 1/1 [==============================] - 0s 4ms/sample - loss: 12.5000
# Epoch 215/250
# 1/1 [==============================] - 0s 5ms/sample - loss: 12.5000
# Epoch 216/250
# 1/1 [==============================] - 0s 4ms/sample - loss: 12.5000
# Epoch 217/250
# 1/1 [==============================] - 0s 3ms/sample - loss: 12.5000
# Epoch 218/250
# 1/1 [==============================] - 0s 3ms/sample - loss: 12.5000
# Epoch 219/250
# 1/1 [==============================] - 0s 3ms/sample - loss: 12.5000
# Epoch 220/250
# 1/1 [==============================] - 0s 7ms/sample - loss: 12.5000
# Epoch 221/250
# 1/1 [==============================] - 0s 3ms/sample - loss: 12.5000
# Epoch 222/250
# 1/1 [==============================] - 0s 6ms/sample - loss: 12.5000
# Epoch 223/250
# 1/1 [==============================] - 0s 5ms/sample - loss: 12.5000
# Epoch 224/250
# 1/1 [==============================] - 0s 4ms/sample - loss: 12.5000
# Epoch 225/250
# 1/1 [==============================] - 0s 3ms/sample - loss: 12.5000
# Epoch 226/250
# 1/1 [==============================] - 0s 3ms/sample - loss: 12.5000
# Epoch 227/250
# 1/1 [==============================] - 0s 4ms/sample - loss: 12.5000
# Epoch 228/250
# 1/1 [==============================] - 0s 2ms/sample - loss: 12.5000
# Epoch 229/250
# 1/1 [==============================] - 0s 3ms/sample - loss: 12.5000
# Epoch 230/250
# 1/1 [==============================] - 0s 5ms/sample - loss: 12.5000
# Epoch 231/250
# 1/1 [==============================] - 0s 5ms/sample - loss: 12.5000
# Epoch 232/250
# 1/1 [==============================] - 0s 4ms/sample - loss: 12.5000
# Epoch 233/250
# 1/1 [==============================] - 0s 4ms/sample - loss: 12.5000
# Epoch 234/250
# 1/1 [==============================] - 0s 4ms/sample - loss: 12.5000
# Epoch 235/250
# 1/1 [==============================] - 0s 5ms/sample - loss: 12.5000
# Epoch 236/250
# 1/1 [==============================] - 0s 4ms/sample - loss: 12.5000
# Epoch 237/250
# 1/1 [==============================] - 0s 6ms/sample - loss: 12.5000
# Epoch 238/250
# 1/1 [==============================] - 0s 4ms/sample - loss: 12.5000
# Epoch 239/250
# 1/1 [==============================] - 0s 3ms/sample - loss: 12.5000
# Epoch 240/250
# 1/1 [==============================] - 0s 5ms/sample - loss: 12.5000
# Epoch 241/250
# 1/1 [==============================] - 0s 6ms/sample - loss: 12.5000
# Epoch 242/250
# 1/1 [==============================] - 0s 4ms/sample - loss: 12.5000
# Epoch 243/250
# 1/1 [==============================] - 0s 5ms/sample - loss: 12.5000
# Epoch 244/250
# 1/1 [==============================] - 0s 4ms/sample - loss: 12.5000
# Epoch 245/250
# 1/1 [==============================] - 0s 4ms/sample - loss: 12.5000
# Epoch 246/250
# 1/1 [==============================] - 0s 6ms/sample - loss: 12.5000
# Epoch 247/250
# 1/1 [==============================] - 0s 3ms/sample - loss: 12.5000
# Epoch 248/250
# 1/1 [==============================] - 0s 5ms/sample - loss: 12.5000
# Epoch 249/250
# 1/1 [==============================] - 0s 6ms/sample - loss: 12.5000
# Epoch 250/250
# 1/1 [==============================] - 0s 3ms/sample - loss: 12.5000
# array(2.9999995, dtype=float32)
