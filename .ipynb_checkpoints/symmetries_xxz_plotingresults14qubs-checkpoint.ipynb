# %% [markdown]
# This is the notebook at which we had the discussion with Marco about what VANS discovers for XXZ model, on Febrauray 17th 2021. The algorithm travels through states that present a magnetization symmetry; while ground and first-excited states have global magnetization equal to zero, local properties differ (first excited present a "flipped configuration" - not sure which a good name for that is - ), which are (more) easily prepared with local transformations compared with the true ground state, which demands a highly no local transformation. VANS navigate the profile of symmetries.

# %%
# %load_ext autoreload
# %autoreload 2
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
import os
import sys
from tqdm import tqdm
#sys.path[0] = "/home/cooper-cooper/Desktop/vans/"
from utilities.evaluator import Evaluator
import os
from utilities.misc import compute_ground_energy
from utilities.variational import VQE
import cirq
import pandas as pd

# %%
grounds = np.array(np.loadtxt("energies.txt"))

# %%
values = pd.read_csv('results/xxz/xxz10first_14.csv',delimiter=",",header=None)

# %%
give_eigens(values[20:],0)
# Out:
# [20.195669358089315,
#  -20.195669358089276,
#  20.054075157198906,
#  -20.05407515719864,
#  19.52514507013936,
#  -19.525145070139317,
#  -19.20775094321947,
#  19.207750943219253,
#  18.662284183797134,
#  18.662284183797038]

# %%
def give_eigens(aaa, index):
    f = aaa[1].to_numpy()[index]
    f = f.replace("{","")
    f = f.replace("}","")
    f = f.replace("\'","")
    return [float(kk.replace(",","")) for kk in f.split()]

# %%
vansenergies=[]
eigens = {}

energies = []
jss=[]
# #
# #
for ind,j in enumerate(tqdm(js)):#5.1,0.1)):
    try:

        args={"n_qubits":14,"problem_config":{"problem" : "XXZ", "g":1.0, "J": j}, "load_displaying":False,
              "specific_folder_name":"XXZLANL"}
        evaluator = Evaluator(args,loading=True, path="../data-vans/",nrun_load=ind)

        vansenergies.append(evaluator.evolution[evaluator.get_best_iteration()][4])

        eigens[j] = give_eigens(values[20:],ind)[:3]
        jss.append(j)
    except Exception as e:
        print(e)
# Out:
# 100%|██████████| 21/21 [00:40<00:00,  1.91s/it]
# [Errno 2] No such file or directory: '../data-vans/XXZ/XXZLANL/run_18/raw_history.pkl'
# [Errno 2] No such file or directory: '../data-vans/XXZ/XXZLANL/run_19/raw_history.pkl'
# [Errno 2] No such file or directory: '../data-vans/XXZ/XXZLANL/run_20/raw_history.pkl'

# %%
jotas=[]
for ind in tqdm(range(18)):
    args={"n_qubits":14,"problem_config":{"problem" : "XXZ", "g":1.0, "J": j}, "load_displaying":False,
          "specific_folder_name":"XXZLANL","load_displaying":True}
    evaluator = Evaluator(args,loading=True, path="../data-vans/",nrun_load=ind)

    ff=evaluator.displaying["information"][:500]
    location_j=ff.find("J\'")
    jhere=float(ff[location_j+5:location_j+8])
    print(jhere)

    jotas.append(jhere)
# Out:
#   6%|▌         | 1/18 [00:02<00:48,  2.84s/it]
# 0.2
#  11%|█         | 2/18 [00:05<00:46,  2.92s/it]
# 0.3
#  17%|█▋        | 3/18 [00:07<00:39,  2.61s/it]
# 0.5
#  22%|██▏       | 4/18 [00:09<00:32,  2.36s/it]
# 0.6
#  28%|██▊       | 5/18 [00:12<00:32,  2.51s/it]
# 0.7
#  33%|███▎      | 6/18 [00:15<00:32,  2.71s/it]
# 0.8
#  39%|███▉      | 7/18 [00:19<00:32,  2.93s/it]
# 0.9
#  44%|████▍     | 8/18 [00:21<00:26,  2.65s/it]
# 1.0
#  50%|█████     | 9/18 [00:24<00:24,  2.75s/it]
# 1.1
#  56%|█████▌    | 10/18 [00:26<00:20,  2.55s/it]
# 1.2
#  61%|██████    | 11/18 [00:29<00:19,  2.81s/it]
# 1.3
#  67%|██████▋   | 12/18 [00:32<00:17,  2.85s/it]
# 1.4
#  72%|███████▏  | 13/18 [00:34<00:12,  2.53s/it]
# 1.5
#  78%|███████▊  | 14/18 [00:36<00:09,  2.30s/it]
# 1.6
#  83%|████████▎ | 15/18 [00:37<00:06,  2.11s/it]
# 1.7
#  89%|████████▉ | 16/18 [00:40<00:04,  2.29s/it]
# 1.8
#  94%|█████████▍| 17/18 [00:43<00:02,  2.55s/it]
# 1.9
# 100%|██████████| 18/18 [00:45<00:00,  2.54s/it]
# 2.0

# %%
np.save("deltas.csv",jotas)

# %%
eigens={}
for ind,j in enumerate(tqdm(js)):
    if j in [0, 0.1, 0.4]:
        pass
    else:
        eigens[j] = np.sort(give_eigens(values[20:],ind))
# Out:
# 100%|██████████| 21/21 [00:00<00:00, 3513.52it/s]

# %%
eigenvalues=np.array(list(eigens.values()))

# %%
eners=np.genfromtxt("8qubitsxxzpaper.csv",delimiter=",")

# %%
pyt=np.load("results/xxz/ges8/ge.npy")

# %%
plt.plot(pyt,label="python")
plt.plot(eners[:,0])
plt.legend()

# %%
import pandas as pd

# %%
#pd.read_csv("8qubitsxxzpaper.txt",header=None,sep='\s*,\s*')
df = pd.read_csv("8qubitsxxzpaper.txt", header=None)
df[0].to_numpy().
# Out:
# array(['{-40.', '{-39.', '{-38.', '{-37.', '{-36.', '{-35.', '{-34.',
#        '{-33.', '{-32.', '{-31.', '{-30.', '{-29.', '{-28.', '{-27.',
#        '{-26.', '{-25.', '{-24.', '{-23.', '{-22.', '{-21.', '{-20.',
#        '{-19.', '{-18.', '{-16.999999999999996', '{-15.999999999999996',
#        '{-15.', '{-14.491168306296144', '{-14.265535861662869',
#        '{-14.261641264514441', '{-14.36225112818592',
#        '{-14.472135954999633', '{-14.6575249116743',
#        '{-15.019524021157325', '{-15.395876806733213',
#        '{-15.785779296154171', '{-16.1884656730844',
#        '{-16.603200703161136', '{-17.02927571648127',
#        '{-17.46600702628342', '{-17.91273589816541',
#        '{-18.36882938695465', '{-18.833681536302848',
#        '{-19.306714589104104', '{-19.94970055336723',
#        '{-20.615401946387916', '{-21.29919816556982',
#        '{-22.00088377523287', '{-22.72013766858928',
#        '{-23.456518955331287', '{-24.209471254591314',
#        '{-24.97833462483714', '{-25.7623634408911',
#        '{-26.560747976308917', '{-27.372637336078082',
#        '{-28.197161655126177', '{-29.033451995914277',
#        '{-29.880656985204226', '{-30.737955795405522',
#        '{-31.604567520834568', '{-32.4797572964275',
#        '{-33.362839666052245', '{-34.2531797592997',
#        '{-35.15019281449943', '{-36.0533425229329', '{-36.96213858858187',
#        '{-37.87613381499003', '{-38.79492095504463',
#        '{-39.71812949492036', '{-40.645422491202766',
#        '{-41.57649353961151', '{-42.511063923270534',
#        '{-43.44887996628583', '{-44.389710602763635',
#        '{-45.33334516075739', '{-46.279591353711815',
#        '{-47.22827346773987', '{-48.17923073076512',
#        '{-49.132315848541296', '{-50.08739369247309',
#        '{-51.044340124591265', '{-52.00304094585471',
#        '{-52.96339095492917'], dtype=object)

# %%
grounds = np.genfromtxt("energies.txt")

# %%
plt.figure(figsize=(10,10))
#plt.plot(np.arange(.2,2.1,.1),grounds[0,:], color="blue",label="ground")
#plt.plot(np.arange(.2,2.1,.1),grounds[1,:], color="red",label="first excited")
plt.scatter(list(jotas),list(vansenergies),size=300,color="red",label="vans")
#plt.plot(jotas,eigenvalues[:,0], color="blue",label="ground")
#plt.plot(jotas,eigenvalues[:,1],color="black",label="first excited")
#plt.plot(jotas,eigenvalues[:,2],'--',label="second excited")
for k in range(7):
    plt.plot(np.arange(.2,2.1,.1),grounds[k,:], label="{}-th excited".format(k))
#    plt.plot(jotas,eigenvalues[:,k],'--',label="{}-th excited".format(k))
    
plt.legend(prop={"size":17})
plt.savefig("14qubitsl.png")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-270-86fe7745415d> in <module>
#       2 #plt.plot(np.arange(.2,2.1,.1),grounds[0,:], color="blue",label="ground")
#       3 #plt.plot(np.arange(.2,2.1,.1),grounds[1,:], color="red",label="first excited")
# ----> 4 plt.scatter(list(jotas),list(vansenergies),size=300,color="red",label="vans")
#       5 #plt.plot(jotas,eigenvalues[:,0], color="blue",label="ground")
#       6 #plt.plot(jotas,eigenvalues[:,1],color="black",label="first excited")
#
# ~/.local/lib/python3.6/site-packages/matplotlib/pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, plotnonfinite, data, **kwargs)
#    2814         verts=verts, edgecolors=edgecolors,
#    2815         plotnonfinite=plotnonfinite, **({"data": data} if data is not
# -> 2816         None else {}), **kwargs)
#    2817     sci(__ret)
#    2818     return __ret
#
# ~/.local/lib/python3.6/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1563     def inner(ax, *args, data=None, **kwargs):
#    1564         if data is None:
# -> 1565             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1566
#    1567         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~/.local/lib/python3.6/site-packages/matplotlib/cbook/deprecation.py in wrapper(*args, **kwargs)
#     356                 f"%(removal)s.  If any parameter follows {name!r}, they "
#     357                 f"should be pass as keyword, not positionally.")
# --> 358         return func(*args, **kwargs)
#     359
#     360     return wrapper
#
# ~/.local/lib/python3.6/site-packages/matplotlib/axes/_axes.py in scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, plotnonfinite, **kwargs)
#    4376         # unless its argument is a masked array.
#    4377         x = np.ma.ravel(x)
# -> 4378         y = np.ma.ravel(y)
#    4379         if x.size != y.size:
#    4380             raise ValueError("x and y must be the same size")
#
# ~/.local/lib/python3.6/site-packages/numpy/ma/core.py in __call__(self, a, *args, **params)
#    6678             a, args[0] = args[0], a
#    6679
# -> 6680         marr = asanyarray(a)
#    6681         method_name = self.__name__
#    6682         method = getattr(type(marr), method_name, None)
#
# ~/.local/lib/python3.6/site-packages/numpy/ma/core.py in asanyarray(a, dtype)
#    7896     if isinstance(a, MaskedArray) and (dtype is None or dtype == a.dtype):
#    7897         return a
# -> 7898     return masked_array(a, dtype=dtype, copy=False, keep_mask=True, subok=True)
#    7899
#    7900
#
# ~/.local/lib/python3.6/site-packages/numpy/ma/core.py in __new__(cls, data, mask, dtype, copy, subok, ndmin, fill_value, keep_mask, hard_mask, shrink, order, **options)
#    2829                 try:
#    2830                     # If data is a sequence of masked array
# -> 2831                     mask = np.array([getmaskarray(m) for m in data],
#    2832                                     dtype=mdtype)
#    2833                 except ValueError:
#
# ~/.local/lib/python3.6/site-packages/numpy/ma/core.py in <listcomp>(.0)
#    2829                 try:
#    2830                     # If data is a sequence of masked array
# -> 2831                     mask = np.array([getmaskarray(m) for m in data],
#    2832                                     dtype=mdtype)
#    2833                 except ValueError:
#
# ~/.local/lib/python3.6/site-packages/numpy/ma/core.py in getmaskarray(arr)
#    1477     mask = getmask(arr)
#    1478     if mask is nomask:
# -> 1479         mask = make_mask_none(np.shape(arr), getattr(arr, 'dtype', None))
#    1480     return mask
#    1481
#
# ~/.local/lib/python3.6/site-packages/numpy/ma/core.py in make_mask_none(newshape, dtype)
#    1694         result = np.zeros(newshape, dtype=MaskType)
#    1695     else:
# -> 1696         result = np.zeros(newshape, dtype=make_mask_descr(dtype))
#    1697     return result
#    1698
#
# ~/.local/lib/python3.6/site-packages/numpy/ma/core.py in make_mask_descr(ndtype)
#    1363
#    1364     """
# -> 1365     return _replace_dtype_fields(ndtype, MaskType)
#    1366
#    1367
#
# ~/.local/lib/python3.6/site-packages/numpy/ma/core.py in _replace_dtype_fields(dtype, primitive_dtype)
#    1328     Arguments are coerced to dtypes first.
#    1329     """
# -> 1330     dtype = np.dtype(dtype)
#    1331     primitive_dtype = np.dtype(primitive_dtype)
#    1332     return _replace_dtype_fields_recursive(dtype, primitive_dtype)
#
# TypeError: data type not understood

# %%
magnetization =

# %%
plt.figure(figsize=(10,10))
plt.plot(grounds[0,:])
plt.plot(jotas,vansenergies,'.',color="red",label="vans")
plt.plot(jotas,eigenvalues[:,0], color="blue",label="ground")
plt.plot(jotas,eigenvalues[:,1],color="black",label="first excited")
plt.plot(jotas,eigenvalues[:,2],'--',label="second excited")
for k in range(3,7):
    plt.plot(jotas,eigenvalues[:,k],'--',label="{}-th excited".format(k))
    
plt.legend()
plt.savefig("14qubits.png")

# %%
plt.figure(figsize=(40,20))
ax1=plt.subplot2grid((1,2),(0,0))
ax2=plt.subplot2grid((1,2),(0,1))


energies = np.array(vansenergies)

ge,ge1,ge2 = np.transpose(np.array(list(eigens.values())))
ge2[np.argmax(ge2)] = ge2[np.argmax(ge2)-1]
lw=8
ax1.scatter(js[jss],np.array(energies),s=200, alpha=0.8, color="blue")
ax1.plot(js,np.array(ge), color="green",alpha=0.75, linewidth=lw, label="ground energy")
ax1.plot(js,np.array(ge1),color="black", alpha=0.75, linewidth=lw, label="first excited")
ax1.plot(js,np.array(ge2), '--',color="red",alpha=0.75, linewidth=lw, label="second excited")
#ax1.plot(js,np.array(ge3), '-.',color="red",alpha=0.75, linewidth=lw, label="third excited")
#ax1.plot(js,np.array(ge4), '--',color="red",alpha=0.75, linewidth=lw, label="third excited")

ax1.legend(prop={"size":20})
#for aut in zip([ge,ge1,ge2], ["first","second",]:
for aut in [ge]:
    ax2.plot(js, np.abs((aut-energies)/np.array(aut)),'.-')

#for ind,b in enumerate(energies):
#    ax2.bar(js[ind],(b-ge[ind])/np.abs(ge[ind]))
ax2.yaxis.tick_right() 
#plt.savefig("xxz_14qubitsmarco.png")

# %%
plt.figure(figsize=(40,20))
ax1=plt.subplot2grid((1,1),(0,0))
plt.title(r'$H = \sum_i^{n} \; X_i X_{i+1} + Y_i Y_{i+1} + \Delta \; Z_i Z_{i+1} + \lambda \sum_i^{n} \sigma_i^{z}$',size=40)
energies = np.array(vansenergies)

ge,ge1,ge2 = np.transpose(np.array(list(eigens.values())))

lw=8
ax1.scatter(js,np.array(energies),s=200, alpha=0.95, color="blue")
ax1.plot(js,np.array(ge), color="black",alpha=0.75, linewidth=lw, label="ground energy")
ax1.plot(js,np.array(ge1),color="red", alpha=0.75, linewidth=lw, label="first excited")
ax1.plot(js,np.array(ge2), '--',color="green",alpha=0.75, linewidth=lw, label="second excited")
ax1.legend(prop={"size":20})
#for aut in zip([ge,ge1,ge2], ["first","second",]:
#for aut in [ge]:
    #ax2.plot(js, np.abs((aut-energies)/np.array(aut)),'.-')

#for ind,b in enumerate(energies):
#    ax2.bar(js[ind],(b-ge[ind])/np.abs(ge[ind]))
#ax2.yaxis.tick_right() 
plt.xlabel(r'$\Delta$',size=40)
plt.ylabel(r'Energy',size=40)
plt.savefig("results/xxz/xxz_8qubitsmarco1.png")

# %%
plt.figure(figsize=(30,10))
ax1=plt.subplot2grid((1,2),(0,0))
ax2=plt.subplot2grid((1,2),(0,1))

energies = np.array(energies)
ge = np.array(ge)

ax1.plot(js,np.log10(-np.array(ge)))
ax1.plot(js,np.log10(-np.array(ge1)),color="black")
ax1.plot(js,np.log10(-np.array(ge2)),color="red")

ax1.plot(js,np.log10(-np.array(energies)),'.')
js=np.arange(0,5.1,0.1)
ax2.plot(js, np.abs((ge-energies)/np.array(ge)),'.-')
ax2.plot(js, np.array(ge1)-np.array(ge2),'.-')

#for ind,b in enumerate(energies):
#    ax2.bar(js[ind],(b-ge[ind])/np.abs(ge[ind]))
ax2.yaxis.tick_right() 
plt.savefig("xxz_8qubitsmarco.png")

# %%
for ind, k in enumerate(ge):
    if k in ge1:
        print(ind)

# %%
np.argmin(np.abs(np.array(ge1)-np.array(ge)))
# Out:
# 9

# %%
args={"n_qubits":8,"problem_config":{"problem" : "XXZ", "g":1.0, "J": -1}, "specific_name":"XXZ/8Q - J {} g 1.0".format(np.round(j,3))}
#evaluator = Evaluator(args,loading=True)

#VQE module, in charge of continuous optimization
vqe_handler = VQE(n_qubits=args["n_qubits"],problem_config=args["problem_config"])
obs = vqe_handler.observable

# %%
item = obs[10].dense(vqe_handler.qubits)

# %%
item.coefficient
# Out:
# (-1+0j)

# %%
def give_kr_prod(mat):
    #matrices list of 2 (or more in principle) matrices
    while len(mat) != 1:
        sm, smf=[],[]
        for ind in range(len(mat)):
            sm.append(mat[ind])
            if ind%2==1 and ind>0:
                smf.append(np.kron(*sm))
                sm=[]
        mat = smf
    return mat[0]

# %%
kk=[np.kron(*[ind_to_2[str(int(ok))] for ok in string[2*ind:2*(ind+1)]]) for ind in range(int(len(string)/2))]

# %%
[[np.kron(*[ok]) for ok in kk[2*ind:2*(ind+1)]] for ind in range(int(len(kk)/2))]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-70-07dd7a24744e> in <module>
# ----> 1 [[np.kron(*[ok]) for ok in kk[2*ind:2*(ind+1)]] for ind in range(int(len(kk)/2))]
#
# <ipython-input-70-07dd7a24744e> in <listcomp>(.0)
# ----> 1 [[np.kron(*[ok]) for ok in kk[2*ind:2*(ind+1)]] for ind in range(int(len(kk)/2))]
#
# <ipython-input-70-07dd7a24744e> in <listcomp>(.0)
# ----> 1 [[np.kron(*[ok]) for ok in kk[2*ind:2*(ind+1)]] for ind in range(int(len(kk)/2))]
#
# <__array_function__ internals> in kron(*args, **kwargs)
#
# TypeError: _kron_dispatcher() missing 1 required positional argument: 'b'

# %%
li = []
for ind,it in range(len(kk)):
    li.append([it]) 
kk
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-73-6784b4de3f73> in <module>
#       1 li = []
# ----> 2 for ind,it in range(len(kk)):
#       3     li.append([it])
#       4 kk
#
# TypeError: 'int' object is not iterable

# %%
[ind_to_2[str(int(ok))] for ok in string[:2]]
# Out:
# [array([[ 1.+0.j,  0.+0.j],
#         [ 0.+0.j, -1.+0.j]]),
#  array([[1., 0.],
#         [0., 1.]])]

# %%
string
# Out:
# array([3, 0, 0, 0, 0, 0, 0, 0], dtype=uint8)
