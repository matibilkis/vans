# %%
from utilities.evaluator import Evaluator
import numpy as np
import matplotlib.pyplot as plt
from IPython import display
from tqdm import tqdm
from utilities.variational import VQE
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
energies=[]
iterations=[]
fcis=[]
js=np.linspace(0.5,2.3,16)
for bond in tqdm(js):
    problem_config ={"problem" : "H2", "geometry": [('H', (0., 0., 0.)), ('H', (0., 0., bond))], "multiplicity":1, "charge":0, "basis":"sto-3g"}
    args={"n_qubits":8,"problem_config":problem_config, "load_displaying":False,"specific_folder_name":"4_bd_{}".format(bond)}
    evaluator = Evaluator(args,loading=True, path="../data-vans/")
    energies.append(evaluator.raw_history[len(list(evaluator.raw_history.keys()))-1][-1])
    iterations.append(len(list(evaluator.raw_history.keys())))
        #VQE module, in charge of continuous optimization
    vqe_handler = VQE(n_qubits=4,noise_config={}, problem_config=problem_config,
                        return_lower_bound=True)
    fcis.append(vqe_handler.lower_bound_energy)
# Out:
# 100%|██████████| 16/16 [00:09<00:00,  1.76it/s]

# %%
energies=np.array(energies)
fcis=np.array(fcis)

plt.figure(figsize=(15,5))
for k in range(3):

    ax = plt.subplot2grid((1,3),(0,k))
    if k==0:
        ax.plot(js,fcis,label="FCI")
        ax.scatter(js,energies,marker='*',s=100,color="black",label="VAns")
        ax.set_ylabel("Energy",size=20)
    elif k==1:
        ax.plot(js,energies-fcis)
        ax.scatter(js, energies-fcis,s=100,label="Energy shift")
        ax.plot(js,np.ones(len(js))*0.0016,'--',color="black",label="Chemical accuracy")
        ax.yaxis.tick_right()
    else:
        for v,b in enumerate(iterations):
            ax.bar(v,b)
        ax.yaxis.tick_right() 
    ax.legend()
    ax.set_xlabel("Bond Lenght [Å]",size=20)
plt.savefig("H2.png")
# Out:
# No handles with labels found to put in legend.

# %%
energies-fcis
# Out:
# array([ 1.94183796e-05,  8.00204809e-08,  4.44319975e-06,  1.33825383e-03,
#         2.24581286e-07,  1.87362568e-07, -3.44940567e-08,  8.61211957e-05,
#         5.58080293e-04,  6.04817106e-08,  8.57140439e-07,  1.07477731e-03,
#         5.75730841e-07,  1.08863014e-04,  1.96855051e-04,  1.05362796e-06])

# %%
#data = np.load("H2/fcisH2.npy")
#data1 = np.load("H2/fcisH2_points16.npy")

js=np.linspace(0.5,2.3,16)
energies=[]
iterations=[]
for j in js:
    print("BOND LENGTH: {}".format(j))
    arguments={"n_qubits":4, "bond_length":j}
    evaluator = Evaluator(loading=True, args=arguments)
    energies.append(evaluator.raw_history[len(list(evaluator.raw_history.keys()))-1][-1])
    iterations.append(len(list(evaluator.raw_history.keys())))
    display.display(evaluator.raw_history[len(list(evaluator.raw_history.keys()))-1][0])
    print("\n")
# Out:
# BOND LENGTH: 0.5
# (0, 0): ─────────────────X───Rx(1.12π)─────X───Rx(0.884π)───X──────────────────────────────────────────────────────────────────────────────────────────────────────@────────────────@───────@───
#                          │                 │                │                                                                                                      │                │       │
# (0, 1): ───Rx(0.528π)────@─────────────────@───Rx(0.427π)───@────────────────────X────────────Rz(0.5π)─────X───────────────────────────────────────────────────────┼────────────────┼───────┼───
#                                                                                  │                         │                                                       │                │       │
# (0, 2): ─────────────────X───Rx(-0.634π)───@────────────────X───Rz(0.206π)───X───@────────────Rz(1.55π)────@────────────Rx(0.488π)───Rz(-1.5π)───X───Rx(-0.514π)───┼────────────────┼───X───┼───
#                          │                 │                │                │                                                                   │                 │                │   │   │
# (0, 3): ───Rx(-0.487π)───@───Rx(-0.176π)───X───Rx(0.496π)───@───Rz(-0.96π)───@───Rz(-1.06π)───Rx(0.286π)───Rz(0.408π)────────────────────────────@───Rz(-0.904π)───X───Rx(0.386π)───X───@───X───
# BOND LENGTH: 0.62
# (0, 0): ───Rx(-π)─────────────────────────────────────X───@───
#                                                       │   │
# (0, 1): ───Rx(π)────@───Rx(-0.058π)───Rz(-0.5π)───@───┼───┼───
#                     │                             │   │   │
# (0, 2): ───Rx(π)────┼─────────────────────────────┼───┼───X───
#                     │                             │   │
# (0, 3): ───Rx(-π)───X───Rx(-π)────────────────────X───@───────
# BOND LENGTH: 0.74
#                                                                                  ┌──┐
# (0, 0): ───Rx(-0.928π)───@─────────────────────────────────────────────────────────@────────────────────────
#                          │                                                         │
# (0, 1): ─────────────────X───@───Rz(0.538π)──────────────────────────────────@────X┼────Rz(1.03π)───X───@───
#                              │                                               │    ││                │   │
# (0, 2): ─────────────────────X───Rx(0.874π)───Rz(-0.996π)───X───Rx(0.874π)───X────┼X────────────────┼───┼───
#                                                             │                     │                 │   │
# (0, 3): ───Rx(π)────────────────────────────────────────────@─────────────────────@─────────────────@───X───
#                                                                                  └──┘
# BOND LENGTH: 0.8599999999999999
#                          ┌─────────┐
# (0, 0): ───Rx(0.5π)───────────────@────Rx(0.15π)────Rz(0.246π)───@────────────────@───X───@───X───Rx(-1.1π)───X───Rx(0.596π)───@───────
#                                   │                              │                │   │   │   │               │                │
# (0, 1): ───Rx(π)──────────────────┼────X─────────────────────────┼────────────────┼───┼───┼───┼───────────────┼────────────────┼───@───
#                                   │    │                         │                │   │   │   │               │                │   │
# (0, 2): ───Rx(-0.089π)────Rz(0.5π)┼────@─────────────────────────┼────────────────┼───@───┼───@───────────────@────────────────┼───┼───
#                                   │                              │                │       │                                    │   │
# (0, 3): ──────────────────────────X────Rx(0.872π)───Rz(-0.69π)───X───Rx(-1.18π)───X───────X────────────────────────────────────X───X───
#                          └─────────┘
# BOND LENGTH: 0.98
# (0, 0): ────────────────────────────────────────────────────────────────────X───Rz(-1.03π)───X────────────────────────────────────────────────────────────────────────────────────────────X───────
#                                                                             │                │                                                                                            │
# (0, 1): ───Rx(π)────────────────────────────────────────────────────────────┼────────────────┼────────────────────────────────────────────────@─────────────Rx(-0.109π)───Rz(-0.5π)───@───@───@───
#                                                                             │                │                                                │                                       │       │
# (0, 2): ───Rx(-0.427π)───X───────────────X─────────────────X───Rz(0.691π)───@───Rz(1.05π)────@───Rx(0.181π)───Rz(-0.875π)───X───Rx(-0.278π)───X───────────────────────────────────────X───────┼───
#                          │               │                 │                                                                │                                                                 │
# (0, 3): ───Rx(0.655π)────@───Rz(1.14π)───@───Rz(-0.215π)───@───Rz(0.659π)───────────────────────────────────────────────────@───Rz(0.515π)────Rx(-0.345π)─────────────────────────────────────X───
# BOND LENGTH: 1.0999999999999999
# (0, 0): ───Rx(π)────────@───Rx(-0.132π)───Rz(-0.5π)───@────────────────────────────
#                         │                             │
# (0, 1): ────────────────X─────────────────────────────X───Rx(π)───@───@────────────
#                                                                   │   │
# (0, 2): ───Rx(π)──────────────────────────────────────────────────┼───X────────────
#                                                                   │
# (0, 3): ───Rx(0.184π)─────────────────────────────────────────────X───Rx(0.816π)───
# BOND LENGTH: 1.2199999999999998
#                                                                                ┌──┐                ┌────────────┐
# (0, 0): ───Rx(1.6π)──────────@───X───Rx(-0.407π)───────────────────────────X────X─────Rx(0.86π)─────X───────────────Rx(-0.765π)───────
#                              │   │                                         │    │                   │
# (0, 1): ─────────────────X───┼───┼─────────────────────────────────────────┼────┼X────@─────────────┼Rx(-0.401π)────@─────────────@───
#                          │   │   │                                         │    ││    │             │               │             │
# (0, 2): ───Rx(-0.684π)───┼───┼───@───Rz(0.5π)──────Rx(0.663π)───Rz(0.5π)───@────┼@────X─────────────┼───────────────X─────────────┼───
#                          │   │                                                  │                   │                             │
# (0, 3): ───Rx(-π)────────@───X──────────────────────────────────────────────────@─────Rx(0.396π)────@─────────────────────────────X───
#                                                                                └──┘                └────────────┘
# BOND LENGTH: 1.3399999999999999
#                                                                                                                                    ┌──────────┐   ┌──┐
# (0, 0): ────────────────────────────────────────────────────────────X───Rz(1.08π)────────────────────────────────────────────────────────────@─────X─────
#                                                                     │                                                                        │     │
# (0, 1): ─────────────────X───Rz(-0.433π)───@───Rz(0.575π)───@───X───@────────────────────────────────────────────────────────────────────────┼─────┼X────
#                          │                 │                │   │                                                                            │     ││
# (0, 2): ─────────────────┼─────────────────┼────────────────┼───┼───X───Rz(-0.447π)───Rx(-0.866π)───Rz(0.554π)───X───Rx(-1.43π)─────Rz(0.44π)┼─────┼@────
#                          │                 │                │   │   │                                            │                           │     │
# (0, 3): ───Rx(-0.464π)───@───Rz(-0.427π)───X───Rx(-π)───────X───@───@───Rz(-0.94π)────Rx(0.394π)────Rz(0.409π)───@───Rx(-0.495π)─────────────X─────@─────
#                                                                                                                                    └──────────┘   └──┘
# BOND LENGTH: 1.46
# (0, 0): ───Rx(0.78π)────Rz(1.5π)──────────────────────────────────────────────────────────────────────────────────────@──────────────────────────────────────────────────────────────────────────────────
#                                                                                                                       │
# (0, 1): ─────────────────────────────────X───@────────Rx(-0.696π)───@───Rz(-0.364π)───@───Rx(-0.695π)───Rz(-0.855π)───X───Rz(-0.293π)───@───Rz(-0.222π)───Rx(π)────────X─────────────────────────────────
#                                          │   │                      │                 │                                                 │                              │
# (0, 2): ───Rx(0.121π)───Rz(-0.46π)───@───┼───X──────────────────────X───Rz(-0.612π)───X───Rx(π)─────────────────────────────────────────X───Rx(π)─────────Rz(0.515π)───┼────────────────@───Rx(0.879π)───
#                                      │   │                                                                                                                             │                │
# (0, 3): ─────────────────────────────X───@───Rx(-π)───Rz(0.878π)───────────────────────────────────────────────────────────────────────────────────────────────────────@───Rz(0.807π)───X────────────────
# BOND LENGTH: 1.5799999999999998
# (0, 0): ───Rx(-0.376π)───X────────────Rx(0.376π)───────X────────────Rz(0.691π)───X───X───
#                          │                             │                         │   │
# (0, 1): ───Rx(-π)────────@─────────────────────────X───@─────────────────────────@───┼───
#                                                    │                                 │
# (0, 2): ──────────────────────────────X────────────@───Rz(0.609π)────────────────────┼───
#                                       │                                              │
# (0, 3): ───Rx(0.254π)────Rz(0.201π)───@──────────────────────────────────────────────@───
# BOND LENGTH: 1.6999999999999997
# (0, 0): ───Rx(π)───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────X───
#                                                                                                                                                                                │
# (0, 1): ───Rx(0.303π)───X───Rz(0.713π)───Rx(-0.272π)───Rz(-0.78π)────────────────────────────────────────────────────────────X─────────────────────────────────────────────────┼───
#                         │                                                                                                    │                                                 │
# (0, 2): ────────────────┼───X────────────Rz(-0.654π)───Rx(0.291π)───Rz(0.378π)────X──────────────────────────────────────────┼───X───Rz(1.0π)──────Rx(-0.355π)───Rz(-0.839π)───@───
#                         │   │                                                     │                                          │   │
# (0, 3): ───Rx(0.499π)───@───@────────────Rz(0.542π)────Rx(-0.5π)────Rz(-0.121π)───@───Rz(0.621π)───Rx(0.631π)───Rz(0.125π)───@───@───Rz(-0.125π)───Rx(-0.5π)─────Rz(-0.274π)───────
# BOND LENGTH: 1.8199999999999998
#                                                                                                                     ┌───────────┐
# (0, 0): ─────────────────────────────────────────────────────────────────X───Rz(-0.197π)─────────────────────────────X──────────────@─────────────────────X───
#                                                                          │                                           │              │                     │
# (0, 1): ─────────────────X───Rz(-0.257π)───Rx(-0.983π)───────────────────┼───X──────────────────────────────────X────┼Rz(0.675π)────X─────────────────────┼───
#                          │                                               │   │                                  │    │                                    │
# (0, 2): ───Rx(0.319π)────@───X─────────────Rz(0.503π)────X───────────────┼───┼──────────────────────────────────┼────┼──────────────X─────────────────X───┼───
#                              │                           │               │   │                                  │    │              │                 │   │
# (0, 3): ───Rx(-0.477π)───────@─────────────Rz(-0.503π)───@───Rx(1.48π)───@───@─────────────Rx(-π)───Rz(1.17π)───@────@──────────────@───Rz(-0.311π)───@───@───
#                                                                                                                     └───────────┘
# BOND LENGTH: 1.9399999999999997
# (0, 0): ───Rx(-0.137π)──────────────X───Rx(1.14π)───────────────────────────────────X───X───
#                                     │                                               │   │
# (0, 1): ───Rx(-π)───────────────────┼───────────────────────────────────────X───────┼───@───
#                                     │                                       │       │
# (0, 2): ───Rx(0.653π)────Rz(1.0π)───@───Rz(-0.505π)───Rx(-0.998π)───Rz(π)───@───@───@───────
#                                                                                 │
# (0, 3): ───Rx(0)────────────────────────────────────────────────────────────────X───────────
# BOND LENGTH: 2.0599999999999996
#                              ┌──┐                                                                                                                           ┌────────────┐
# (0, 0): ───Rx(-0.626π)───@─────@────Rz(0.765π)──────────────────────────────@────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#                          │     │                                            │
# (0, 1): ─────────────────┼────X┼────────────────────────────────────────────┼───@───Rx(-0.543π)───@────────────Rz(0.78π)────Rx(π)─────────Rz(-0.697π)───@────@───────────────X───@───Rx(-0.486π)───Rz(0.181π)───@────────────────
#                          │    ││                                            │   │                 │                                                     │    │               │   │                              │
# (0, 2): ─────────────────X────@┼────────────────────────────────────────────┼───┼─────────────────X────────────Rz(0.503π)───Rx(-0.712π)───Rz(π)─────────X────┼Rx(-0.712π)────@───┼──────────────────────────────┼────────────────
#                                │                                            │   │                                                                            │                   │                              │
# (0, 3): ───────────────────────X────Rz(-0.423π)───Rx(0.416π)───Rz(-0.87π)───X───X───Rz(-0.19π)────Rx(0.867π)───Rz(0.942π)────────────────────────────────────X───────────────────X───Rx(-0.361π)────────────────X───Rx(0.814π)───
#                              └──┘                                                                                                                           └────────────┘
# BOND LENGTH: 2.1799999999999997
# (0, 0): ──────────────────────────────────────────────X───Rz(0.642π)───Rx(0.955π)───Rz(-0.5π)───X───@───X───
#                                                       │                                         │   │   │
# (0, 1): ────────────────────X────────────Rz(0.411π)───┼─────────────────────────────────────────┼───┼───┼───
#                             │                         │                                         │   │   │
# (0, 2): ───Rx(0.604π)───@───@────────────Rz(0.089π)───┼─────────────────────────────────────────┼───X───┼───
#                         │                             │                                         │       │
# (0, 3): ────────────────X───Rx(0.964π)───Rz(-0.78π)───@───Rz(0.637π)────────────────────────────@───────@───
# BOND LENGTH: 2.3
#                                       ┌──────────────────────┐   ┌─────────┐                                                          ┌─────────┐
# (0, 0): ───Rx(-0.5π)─────@─────────────Rx(-0.494π)────────────────X────────────Rz(0.494π)───Rx(0.497π)───Rz(0.508π)───X───@────────────X────────────Rz(-0.839π)───Rx(-0.557π)───Rz(0.595π)───X───Rx(0.823π)───X───
#                          │                                        │                                                   │   │            │                                                     │                │
# (0, 1): ───Rx(π)─────────┼─────────────X──────────────────────────┼Rz(1.1π)───────────────────────────────────────────┼───┼────────────┼─────────────────────────────────────────────────────┼────────────────┼───
#                          │             │                          │                                                   │   │            │                                                     │                │
# (0, 2): ───Rx(0.499π)────X─────────────┼──────────Rz(-0.843π)─────┼───────────────────────────────────────────────────┼───X────────────┼Rz(1.0π)─────────────────────────────────────────────┼────────────────@───
#                                        │                          │                                                   │                │                                                     │
# (0, 3): ───Rx(-0.414π)───Rz(0.707π)────@──────────────────────────@────────────Rz(0.453π)─────────────────────────────@───Rz(0.75π)────@────────────Rz(-0.421π)──────────────────────────────@────────────────────
#                                       └──────────────────────┘   └─────────┘                                                          └─────────┘

# %%
plt.figure(figsize=(15,5))
for k in range(3):

    ax = plt.subplot2grid((1,3),(0,k))
    if k==0:
        ax.plot(data[0],data[1],label="FCI")
        ax.scatter(js,energies,marker='*',s=100,color="black",label="Vans - 60 runs")
        ax.set_ylabel("Energy [Ha]",size=20)
    elif k==1:
        ax.plot(js,energies-data1[1])
        ax.scatter(js, energies-data1[1],s=100,label="Energy shift")
        ax.plot(js,np.ones(len(js))*0.0016,'--',color="black",label="Chemical accuracy")
        ax.yaxis.tick_right()
    else:
        for v,b in enumerate(iterations):
            ax.bar(v,b)
        ax.yaxis.tick_right() 
        
    ax.legend()

    ax.set_xlabel("Bond Lenght [Å]",size=20)
plt.savefig("second_run.png")
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# Energy differences: there's a negative one !

# %%
energies-data1[1]
# Out:
# array([ 1.94183796e-05,  8.00204809e-08,  4.44319975e-06,  1.33825383e-03,
#         2.24581286e-07,  1.87362568e-07, -3.44940567e-08,  8.61211957e-05,
#         5.58080293e-04,  6.04817106e-08,  8.57140439e-07,  1.07477731e-03,
#         5.75730841e-07,  1.08863014e-04,  1.96855051e-04,  1.05362796e-06])
