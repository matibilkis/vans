# %%
from utilities.evaluator import Evaluator
import numpy as np
import matplotlib.pyplot as plt
from IPython import display
from utilities.misc import dict_to_json
# %load_ext autoreload
# %autoreload 2

# %%
bond=1.5
problem_config={"problem" : "H4", "geometry": str([('H', (0., 0., 0.)), ('H', (0., 0., bond)), ('H', (0., 0., 2*bond)), ('H', (0., 0., 3*bond))]).replace("'",""), "multiplicity":1, "charge":0, "basis":"sto-3g"}
arguss= {"n_qubits":8,"problem_config":problem_config,"specific_name":"_rate_{}".format(1.0), "noise_config":{}}
evaluator = Evaluator(args=arguss,loading=True,path="../data-vans/",nrun_load=3)

# %%
evaluator.raw_history
# Out:
# {0: [(0, 0): ───Rx(1.12π)────Rz(1.47π)────@───Rx(1.96π)───Rz(-1.9π)─────────────────@───────────Rx(1.13π)───Rz(1.98π)────────────────@─────────────Rx(π)────────Rz(0.209π)────────────────@────────────────────────────────────────────────────────────────────
#                                      │                                         │                                                │                                                    │
# (0, 1): ───Rx(1.05π)────Rz(0.741π)───X───@───────────Rx(0.147π)───Rz(0.575π)───X───────────@───────────Rx(2π)──────Rz(1.59π)────X─────────────@────────────Rx(π)────────Rz(0.402π)───X────────────@───────────────────────────────────────────────────────
#                                          │                                                 │                                                  │                                                   │
# (0, 2): ───Rx(0.499π)───Rz(0.5π)─────────X───────────@────────────Rx(1.02π)────Rz(1.32π)───X───────────@───────────Rx(1.5π)─────Rz(-0.032π)───X────────────@────────────Rx(0)────────Rz(0.083π)───X──────────@────────────────────────────────────────────
#                                                      │                                                 │                                                   │                                                 │
# (0, 3): ───Rx(0.809π)───Rz(2π)───────────────────────X────────────@────────────Rx(1.17π)───Rz(1.82π)───X───────────@────────────Rx(0)─────────Rz(0.866π)───X────────────@────────────Rx(π)────────Rz(1.0π)───X───────────@────────────────────────────────
#                                                                   │                                                │                                                    │                                                │
# (0, 4): ───Rx(0.5π)─────Rz(0.5π)──────────────────────────────────X────────────@───────────Rx(1.24π)───Rz(π)───────X────────────@─────────────Rx(0.5π)─────Rz(-0.05π)───X────────────@────────────Rx(0)──────Rz(1.48π)───X────────────@───────────────────
#                                                                                │                                                │                                                    │                                                │
# (0, 5): ───Rx(0.265π)───Rz(0)──────────────────────────────────────────────────X───────────@───────────Rx(1.5π)────Rz(1.5π)─────X─────────────@────────────Rx(1.18π)────Rz(1.5π)─────X────────────@──────────Rx(1.19π)───Rz(0.906π)───X───────────@───────
#                                                                                            │                                                  │                                                   │                                               │
# (0, 6): ───Rx(-0.5π)────Rz(0.753π)─────────────────────────────────────────────────────────X───────────@───────────Rx(1.5π)─────Rz(0.212π)────X────────────@────────────Rx(0.5π)─────Rz(0.5π)─────X──────────@───────────Rx(1.32π)────Rz(1.9π)────X───@───
#                                                                                                        │                                                   │                                                 │                                        │
# (0, 7): ───Rx(1.22π)────Rz(2π)─────────────────────────────────────────────────────────────────────────X───────────Rx(0.904π)───Rz(1.63π)──────────────────X────────────Rx(0.241π)───Rz(0.5π)────────────────X───────────Rx(2π)───────Rz(1.69π)───────X───,
#   <tf.Tensor: shape=(), dtype=float32, numpy=-1.7944671>,
#   [64,
#    56,
#    65,
#    57,
#    66,
#    58,
#    67,
#    59,
#    68,
#    60,
#    69,
#    61,
#    70,
#    62,
#    71,
#    63,
#    0,
#    8,
#    16,
#    24,
#    32,
#    40,
#    48,
#    64,
#    56,
#    65,
#    57,
#    66,
#    58,
#    67,
#    59,
#    68,
#    60,
#    69,
#    61,
#    70,
#    62,
#    71,
#    63,
#    0,
#    8,
#    16,
#    24,
#    32,
#    40,
#    48,
#    64,
#    56,
#    65,
#    57,
#    66,
#    58,
#    67,
#    59,
#    68,
#    60,
#    69,
#    61,
#    70,
#    62,
#    71,
#    63,
#    0,
#    8,
#    16,
#    24,
#    32,
#    40,
#    48,
#    64,
#    56,
#    65,
#    57,
#    66,
#    58,
#    67,
#    59,
#    68,
#    60,
#    69,
#    61,
#    70,
#    62,
#    71,
#    63,
#    0,
#    8,
#    16,
#    24,
#    32,
#    40,
#    48],
#   {'th_0': 3.5172186,
#    'th_1': 4.608092,
#    'th_2': 3.2951148,
#    'th_3': 2.3272712,
#    'th_4': 1.568656,
#    'th_5': 1.5708678,
#    'th_6': 2.5410244,
#    'th_7': 6.2834034,
#    'th_8': 1.5707718,
#    'th_9': 1.570787,
#    'th_10': 0.831973,
#    'th_11': -4.545253e-05,
#    'th_12': -1.5707794,
#    'th_13': 2.3655722,
#    'th_14': 3.8449202,
#    'th_15': 6.2831817,
#    'th_16': 6.1437654,
#    'th_17': 6.596801,
#    'th_18': 0.4618704,
#    'th_19': 1.8058933,
#    'th_20': 3.2176685,
#    'th_21': 4.14219,
#    'th_22': 3.666101,
#    'th_23': 5.7130203,
#    'th_24': 3.8804889,
#    'th_25': 3.141589,
#    'th_26': 4.712442,
#    'th_27': 4.7124095,
#    'th_28': 4.7123613,
#    'th_29': 0.6645403,
#    'th_30': 2.8407722,
#    'th_31': 5.125387,
#    'th_32': 3.539579,
#    'th_33': 6.2314267,
#    'th_34': 6.2832055,
#    'th_35': 5.0029035,
#    'th_36': 4.7104445,
#    'th_37': -0.10161363,
#    'th_38': 1.6622475e-06,
#    'th_39': 2.7220407,
#    'th_40': 1.5707759,
#    'th_41': -0.15708147,
#    'th_42': 3.7026105,
#    'th_43': 4.7123823,
#    'th_44': 1.5708069,
#    'th_45': 1.5708323,
#    'th_46': 0.7558227,
#    'th_47': 1.5707302,
#    'th_48': 3.1416364,
#    'th_49': 0.65700316,
#    'th_50': 3.1416283,
#    'th_51': 1.2629424,
#    'th_52': 3.822278e-06,
#    'th_53': 0.26135343,
#    'th_54': 3.141587,
#    'th_55': 3.1543765,
#    'th_56': 1.3740521e-07,
#    'th_57': 4.660989,
#    'th_58': 3.7382002,
#    'th_59': 2.846669,
#    'th_60': 4.143931,
#    'th_61': 5.9708023,
#    'th_62': 6.283181,
#    'th_63': 5.294846},
#   <tf.Tensor: shape=(), dtype=float32, numpy=-1.7944671>],
#  1: [(0, 0): ───Rx(π)─────────────────────@───Rx(π)───────────────────────────@──────────Rx(0.133π)────────────────────────────@────────────Rx(0.932π)───Rz(0.504π)───@─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#                                      │                                   │                                                │                                      │
# (0, 1): ───Rx(-1.63π)───Rz(0.987π)───X───@───────Rx(1.83π)───Rz(1.7π)────X──────────@────────────Rx(-1.5π)───Rz(0.5π)─────X────────────@─────────────────────────X────────────@──────────────────────────────────────────────────────────────────────────────────────────────────────────X───Rz(0.5π)───Rx(0.5π)───Rz(1.43π)───X───
#                                          │                                          │                                                  │                                      │                                                                                                          │                                     │
# (0, 2): ───Rx(0.509π)────────────────────X───────@───────────Rz(1.81π)──────────────X────────────@───────────Rx(1.71π)────Rz(0.504π)───X────────────@────────────Rx(1.5π)─────X──────────────────────────────────────────────────────────────────────────────────────────@───────────────┼─────────────────────────────────────┼───
#                                                  │                                               │                                                  │                                                                                                                    │               │                                     │
# (0, 3): ───Rx(0.501π)───Rz(π)────────────────────X───────────@───────────Rx(0.5π)───Rz(1.5π)─────X───────────@────────────Rx(0.771π)───Rz(0.772π)───X────────────@────────────Rx(1.5π)───Rz(π)─────────────────────────────────X────────────Rz(0.431π)───Rx(π)───────X───X───────────@───@───Rz(2.0π)──────────────────────────@───
#                                                              │                                               │                                                   │                                                             │                                     │               │
# (0, 4): ───Rx(1.6π)─────Rz(1.77π)────────────────────────────X───────────@──────────Rx(1.5π)─────Rz(1.5π)────X────────────@────────────Rx(0.5π)──────────────────X────────────@──────────Rx(0.507π)───Rz(0.51π)────────────────┼─────────────────────────────────────┼───────────────X───@─────────────────────────────────────────
#                                                                          │                                                │                                                   │                                                │                                     │                   │
# (0, 5): ─────────────────────────────────────────────────────────────────X──────────@────────────Rx(π)───────Rz(1.51π)────X────────────@────────────Rx(0.5π)─────Rz(1.5π)─────X──────────@────────────Rx(1.5π)────Rz(-0.21π)───┼─────────────────────────────────────┼───────────────────X───@─────────────────────────────────────
#                                                                                     │                                                  │                                                 │                                     │                                     │                       │
# (0, 6): ───Rx(0.244π)───Rz(1.0π)────────────────────────────────────────────────────X────────────@───────────Rx(0.5π)─────Rz(π)────────X────────────@────────────Rx(0.832π)───Rz(1.5π)───X────────────@───────────Rx(1.49π)────@────────────Rx(1.5π)─────Rz(1.48π)───@───Rz(1.02π)───────────X──────────@──────────────────────────
#                                                                                                  │                                                  │                                                 │                                                                                                 │
# (0, 7): ───Rx(1.63π)─────────────────────────────────────────────────────────────────────────────X───────────Rx(0.428π)───Rz(1.0π)──────────────────X────────────Rx(0.555π)───Rz(0.5π)────────────────X───────────Rx(π)────────Rz(0.216π)───────────────────────────────────────────────────────────────X──────────────────────────,
#   array(-1.9379661, dtype=float32),
#   [64,
#    65,
#    57,
#    66,
#    67,
#    59,
#    68,
#    60,
#    70,
#    62,
#    71,
#    0,
#    8,
#    16,
#    24,
#    32,
#    40,
#    48,
#    64,
#    65,
#    57,
#    58,
#    67,
#    59,
#    68,
#    60,
#    69,
#    61,
#    70,
#    62,
#    71,
#    63,
#    0,
#    8,
#    16,
#    24,
#    32,
#    40,
#    48,
#    64,
#    65,
#    57,
#    66,
#    58,
#    67,
#    59,
#    68,
#    69,
#    61,
#    70,
#    62,
#    71,
#    63,
#    0,
#    8,
#    16,
#    24,
#    32,
#    40,
#    48,
#    64,
#    56,
#    66,
#    67,
#    59,
#    68,
#    60,
#    69,
#    61,
#    70,
#    45,
#    70,
#    62,
#    59,
#    67,
#    45,
#    62,
#    71,
#    63,
#    0,
#    8,
#    16,
#    24,
#    32,
#    22,
#    59,
#    57,
#    65,
#    57,
#    22,
#    40,
#    48],
#   {'th_0': 3.1413631,
#    'th_1': 7.4601974,
#    'th_2': 3.1018574,
#    'th_3': 1.5993768,
#    'th_4': 1.5731406,
#    'th_5': 3.1408343,
#    'th_6': 5.034897,
#    'th_7': 5.5586467,
#    'th_8': 0.7672975,
#    'th_9': 3.1452353,
#    'th_10': 5.109173,
#    'th_11': 3.141735,
#    'th_12': 5.7494264,
#    'th_13': 5.336988,
#    'th_14': 5.697442,
#    'th_15': 1.5701469,
#    'th_16': 4.7123647,
#    'th_17': 4.712415,
#    'th_18': 4.7123466,
#    'th_19': 3.1415923,
#    'th_20': 4.7594705,
#    'th_21': 1.5707662,
#    'th_22': 3.1417837,
#    'th_23': 1.3457792,
#    'th_24': 3.155163,
#    'th_25': 0.41633666,
#    'th_26': 7.8520417,
#    'th_27': 1.5694691,
#    'th_28': 5.3816895,
#    'th_29': 1.5834975,
#    'th_30': 2.4223144,
#    'th_31': 2.4241712,
#    'th_32': 1.5707278,
#    'th_33': 1.5708358,
#    'th_34': 4.7138734,
#    'th_35': 2.6137733,
#    'th_36': 4.712396,
#    'th_37': 1.7425445,
#    'th_38': 1.5708591,
#    'th_39': 2.9270067,
#    'th_40': 1.583378,
#    'th_41': 4.712339,
#    'th_42': 4.7123933,
#    'th_43': 3.1416006,
#    'th_44': 1.5913817,
#    'th_45': 1.6012119,
#    'th_46': 4.7122865,
#    'th_47': -0.6592186,
#    'th_48': 4.6735888,
#    'th_49': 4.7123895,
#    'th_50': 4.6422477,
#    'th_51': 1.3554457,
#    'th_52': 3.14159,
#    'th_53': 3.2127602,
#    'th_54': 3.1415973,
#    'th_55': 0.6792365,
#    'th_56': 6.2793627,
#    'th_57': 1.570418,
#    'th_58': 1.5722309,
#    'th_59': 4.487984},
#   array(-1.9379661, dtype=float32)],
#  2: [(0, 0): ───Rx(1.64π)────────────────@───Rx(0.365π)───────────@─────────────────────────────────────────@────────────Rx(0.875π)───Rz(1.5π)───@─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#                                     │                        │                                         │                                    │
# (0, 1): ───Rx(1.5π)─────Rz(1.5π)────X───@────────────Rz(π)───X───@───────────Rx(0.206π)───Rz(0.594π)───X─────────────────────────@──────────X────────────────────────────────────@────────────────────────────────────────────────────────────────────────X─────────────Rz(0.5π)───Rx(0.5π)───X───
#                                         │                        │                                                               │                                               │                                                                        │                                   │
# (0, 2): ───Rx(0.493π)───────────────────X────────────@───────────X────────────────────────@────────────Rx(0.258π)───Rz(0.5π)─────X──────────@──────────Rx(1.5π)────Rz(1.82π)─────X───────────────────────────────────────────────────────@────────────────┼───────────────────────────────────┼───
#                                                      │                                    │                                                 │                                                                                            │                │                                   │
# (0, 3): ───Rx(0.204π)───Rz(π)────────────────────────X───────@───Rx(1.08π)───Rz(0.5π)─────X────────────@────────────Rx(0.458π)──────────────X──────────@───────────Rx(1.5π)───────────────────────────────────────────X──────────────X───X────────────@───@───────────────────────────────────@───
#                                                              │                                         │                                               │                                                              │              │                │
# (0, 4): ───Rx(0.5π)─────Rz(1.34π)────────────────────────────X───@───────────Rx(0.5π)─────Rz(0.5π)─────X────────────@────────────Rx(0.5π)──────────────X───────────@─────────────Rx(1.57π)───Rz(1.59π)────────────────┼──────────────┼────────────────X───Rx(-0.236π)───@─────────────────────────
#                                                                  │                                                  │                                              │                                                  │              │                                  │
# (0, 5): ─────────────────────────────────────────────────────────X───────────@────────────Rz(1.5π)──────────────────X────────────@──────────Rx(0.5π)───Rz(1.19π)───X─────────────@───────────Rz(1.43π)────────────────┼──────────────┼──────────────────────────────────X──────────@──────────────
#                                                                              │                                                   │                                               │                                    │              │                                             │
# (0, 6): ───Rx(1.78π)─────────────────────────────────────────────────────────X────────────@────────────Rx(0.5π)─────Rz(0.5π)─────X──────────@──────────Rx(-1.5π)───Rz(-0.182π)───X───────────@───────────Rx(0.916π)───@───Rx(0.5π)───@───Rz(0.306π)────────────────────────────────X──────────@───
#                                                                                           │                                                 │                                                │                                                                                                │
# (0, 7): ───Rx(1.42π)──────────────────────────────────────────────────────────────────────X────────────Rx(0.58π)────Rz(1.42π)───────────────X──────────Rx(0.5π)────Rz(0.818π)────────────────X───────────Rz(1.43π)────────────────────────────────────────────────────────────────────────────X───,
#   array(-1.8271545, dtype=float32),
#   [64,
#    65,
#    57,
#    66,
#    67,
#    59,
#    68,
#    60,
#    70,
#    71,
#    0,
#    8,
#    16,
#    24,
#    32,
#    40,
#    48,
#    64,
#    57,
#    67,
#    59,
#    68,
#    60,
#    61,
#    70,
#    62,
#    71,
#    63,
#    0,
#    8,
#    16,
#    24,
#    32,
#    40,
#    48,
#    65,
#    57,
#    66,
#    58,
#    67,
#    68,
#    69,
#    61,
#    70,
#    62,
#    71,
#    63,
#    0,
#    8,
#    16,
#    24,
#    32,
#    40,
#    48,
#    64,
#    56,
#    67,
#    68,
#    60,
#    61,
#    70,
#    45,
#    70,
#    45,
#    62,
#    63,
#    0,
#    66,
#    58,
#    8,
#    16,
#    24,
#    68,
#    32,
#    22,
#    57,
#    65,
#    22,
#    40,
#    48],
#   {'th_0': 5.137809,
#    'th_1': 4.7123766,
#    'th_2': 4.712764,
#    'th_3': 1.5488229,
#    'th_4': 0.64107406,
#    'th_5': 3.1415431,
#    'th_6': 1.5708276,
#    'th_7': 4.219248,
#    'th_8': 5.6070247,
#    'th_9': 4.462449,
#    'th_10': 1.1454339,
#    'th_11': 3.1417966,
#    'th_12': 3.3926332,
#    'th_13': 1.5707928,
#    'th_14': 1.5707756,
#    'th_15': 1.5708144,
#    'th_16': 4.71237,
#    'th_17': 1.5707455,
#    'th_18': 1.5707787,
#    'th_19': 1.8207413,
#    'th_20': 4.4492183,
#    'th_21': 0.6464097,
#    'th_22': 1.8652302,
#    'th_23': 0.81193644,
#    'th_24': 1.5708102,
#    'th_25': 1.4373796,
#    'th_26': 1.5707392,
#    'th_27': 1.5708318,
#    'th_28': 3.7250595,
#    'th_29': 7.8539696,
#    'th_30': -0.57282996,
#    'th_31': 1.5707852,
#    'th_32': 2.5687542,
#    'th_33': 2.7492664,
#    'th_34': 4.7121987,
#    'th_35': 4.71212,
#    'th_36': 4.949193,
#    'th_37': 4.979555,
#    'th_38': 4.5004864,
#    'th_39': 2.878393,
#    'th_40': 1.5707377,
#    'th_41': 0.96283245,
#    'th_42': 4.5006585,
#    'th_43': 4.7123427,
#    'th_44': 5.7291183,
#    'th_45': -0.7408508,
#    'th_46': 1.5708992,
#    'th_47': 1.5707963},
#   array(-1.9379661, dtype=float32)],
#  3: [(0, 0): ───Rx(1.64π)────────────────@───Rx(0.365π)───────────@─────────────────────────────────────────@────────────Rx(0.875π)───Rz(1.5π)───@─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#                                     │                        │                                         │                                    │
# (0, 1): ───Rx(1.5π)─────Rz(1.5π)────X───@────────────Rz(π)───X───@───────────Rx(0.206π)───Rz(0.594π)───X─────────────────────────@──────────X────────────────────────────────────@────────────────────────────────────────────────────────────────────────X─────────────Rz(0.5π)───Rx(0.5π)───X───
#                                         │                        │                                                               │                                               │                                                                        │                                   │
# (0, 2): ───Rx(0.493π)───────────────────X────────────@───────────X────────────────────────@────────────Rx(0.258π)───Rz(0.5π)─────X──────────@──────────Rx(1.5π)────Rz(1.82π)─────X───────────────────────────────────────────────────────@────────────────┼───────────────────────────────────┼───
#                                                      │                                    │                                                 │                                                                                            │                │                                   │
# (0, 3): ───Rx(0.204π)───Rz(π)────────────────────────X───────@───Rx(1.08π)───Rz(0.5π)─────X────────────@────────────Rx(0.458π)──────────────X──────────@───────────Rx(1.5π)───────────────────────────────────────────X──────────────X───X────────────@───@───────────────────────────────────@───
#                                                              │                                         │                                               │                                                              │              │                │
# (0, 4): ───Rx(0.5π)─────Rz(1.34π)────────────────────────────X───@───────────Rx(0.5π)─────Rz(0.5π)─────X────────────@────────────Rx(0.5π)──────────────X───────────@─────────────Rx(1.57π)───Rz(1.59π)────────────────┼──────────────┼────────────────X───Rx(-0.236π)───@─────────────────────────
#                                                                  │                                                  │                                              │                                                  │              │                                  │
# (0, 5): ─────────────────────────────────────────────────────────X───────────@────────────Rz(1.5π)──────────────────X────────────@──────────Rx(0.5π)───Rz(1.19π)───X─────────────@───────────Rz(1.43π)────────────────┼──────────────┼──────────────────────────────────X──────────@──────────────
#                                                                              │                                                   │                                               │                                    │              │                                             │
# (0, 6): ───Rx(1.78π)─────────────────────────────────────────────────────────X────────────@────────────Rx(0.5π)─────Rz(0.5π)─────X──────────@──────────Rx(-1.5π)───Rz(-0.182π)───X───────────@───────────Rx(0.916π)───@───Rx(0.5π)───@───Rz(0.306π)────────────────────────────────X──────────@───
#                                                                                           │                                                 │                                                │                                                                                                │
# (0, 7): ───Rx(1.42π)──────────────────────────────────────────────────────────────────────X────────────Rx(0.58π)────Rz(1.42π)───────────────X──────────Rx(0.5π)────Rz(0.818π)────────────────X───────────Rz(1.43π)────────────────────────────────────────────────────────────────────────────X───,
#   array(-1.8271545, dtype=float32),
#   [64,
#    65,
#    57,
#    66,
#    67,
#    59,
#    68,
#    60,
#    70,
#    71,
#    0,
#    8,
#    16,
#    24,
#    32,
#    40,
#    48,
#    64,
#    57,
#    67,
#    59,
#    68,
#    60,
#    61,
#    70,
#    62,
#    71,
#    63,
#    0,
#    8,
#    16,
#    24,
#    32,
#    40,
#    48,
#    65,
#    57,
#    66,
#    58,
#    67,
#    68,
#    69,
#    61,
#    70,
#    62,
#    71,
#    63,
#    0,
#    8,
#    16,
#    24,
#    32,
#    40,
#    48,
#    64,
#    56,
#    67,
#    68,
#    60,
#    61,
#    70,
#    45,
#    70,
#    45,
#    62,
#    63,
#    0,
#    66,
#    58,
#    8,
#    16,
#    24,
#    68,
#    32,
#    22,
#    57,
#    65,
#    22,
#    40,
#    48],
#   {'th_0': 5.137809,
#    'th_1': 4.7123766,
#    'th_2': 4.712764,
#    'th_3': 1.5488229,
#    'th_4': 0.64107406,
#    'th_5': 3.1415431,
#    'th_6': 1.5708276,
#    'th_7': 4.219248,
#    'th_8': 5.6070247,
#    'th_9': 4.462449,
#    'th_10': 1.1454339,
#    'th_11': 3.1417966,
#    'th_12': 3.3926332,
#    'th_13': 1.5707928,
#    'th_14': 1.5707756,
#    'th_15': 1.5708144,
#    'th_16': 4.71237,
#    'th_17': 1.5707455,
#    'th_18': 1.5707787,
#    'th_19': 1.8207413,
#    'th_20': 4.4492183,
#    'th_21': 0.6464097,
#    'th_22': 1.8652302,
#    'th_23': 0.81193644,
#    'th_24': 1.5708102,
#    'th_25': 1.4373796,
#    'th_26': 1.5707392,
#    'th_27': 1.5708318,
#    'th_28': 3.7250595,
#    'th_29': 7.8539696,
#    'th_30': -0.57282996,
#    'th_31': 1.5707852,
#    'th_32': 2.5687542,
#    'th_33': 2.7492664,
#    'th_34': 4.7121987,
#    'th_35': 4.71212,
#    'th_36': 4.949193,
#    'th_37': 4.979555,
#    'th_38': 4.5004864,
#    'th_39': 2.878393,
#    'th_40': 1.5707377,
#    'th_41': 0.96283245,
#    'th_42': 4.5006585,
#    'th_43': 4.7123427,
#    'th_44': 5.7291183,
#    'th_45': -0.7408508,
#    'th_46': 1.5708992,
#    'th_47': 1.5707963},
#   array(-1.9379661, dtype=float32)],
#  4: [(0, 0): ───Rx(1.64π)────────────────@───Rx(0.365π)───────────@─────────────────────────────────────────@────────────Rx(0.875π)───Rz(1.5π)───@─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#                                     │                        │                                         │                                    │
# (0, 1): ───Rx(1.5π)─────Rz(1.5π)────X───@────────────Rz(π)───X───@───────────Rx(0.206π)───Rz(0.594π)───X─────────────────────────@──────────X────────────────────────────────────@────────────────────────────────────────────────────────────────────────X─────────────Rz(0.5π)───Rx(0.5π)───X───
#                                         │                        │                                                               │                                               │                                                                        │                                   │
# (0, 2): ───Rx(0.493π)───────────────────X────────────@───────────X────────────────────────@────────────Rx(0.258π)───Rz(0.5π)─────X──────────@──────────Rx(1.5π)────Rz(1.82π)─────X───────────────────────────────────────────────────────@────────────────┼───────────────────────────────────┼───
#                                                      │                                    │                                                 │                                                                                            │                │                                   │
# (0, 3): ───Rx(0.204π)───Rz(π)────────────────────────X───────@───Rx(1.08π)───Rz(0.5π)─────X────────────@────────────Rx(0.458π)──────────────X──────────@───────────Rx(1.5π)───────────────────────────────────────────X──────────────X───X────────────@───@───────────────────────────────────@───
#                                                              │                                         │                                               │                                                              │              │                │
# (0, 4): ───Rx(0.5π)─────Rz(1.34π)────────────────────────────X───@───────────Rx(0.5π)─────Rz(0.5π)─────X────────────@────────────Rx(0.5π)──────────────X───────────@─────────────Rx(1.57π)───Rz(1.59π)────────────────┼──────────────┼────────────────X───Rx(-0.236π)───@─────────────────────────
#                                                                  │                                                  │                                              │                                                  │              │                                  │
# (0, 5): ─────────────────────────────────────────────────────────X───────────@────────────Rz(1.5π)──────────────────X────────────@──────────Rx(0.5π)───Rz(1.19π)───X─────────────@───────────Rz(1.43π)────────────────┼──────────────┼──────────────────────────────────X──────────@──────────────
#                                                                              │                                                   │                                               │                                    │              │                                             │
# (0, 6): ───Rx(1.78π)─────────────────────────────────────────────────────────X────────────@────────────Rx(0.5π)─────Rz(0.5π)─────X──────────@──────────Rx(-1.5π)───Rz(-0.182π)───X───────────@───────────Rx(0.916π)───@───Rx(0.5π)───@───Rz(0.306π)────────────────────────────────X──────────@───
#                                                                                           │                                                 │                                                │                                                                                                │
# (0, 7): ───Rx(1.42π)──────────────────────────────────────────────────────────────────────X────────────Rx(0.58π)────Rz(1.42π)───────────────X──────────Rx(0.5π)────Rz(0.818π)────────────────X───────────Rz(1.43π)────────────────────────────────────────────────────────────────────────────X───,
#   array(-1.8271545, dtype=float32),
#   [64,
#    65,
#    57,
#    66,
#    67,
#    59,
#    68,
#    60,
#    70,
#    71,
#    0,
#    8,
#    16,
#    24,
#    32,
#    40,
#    48,
#    64,
#    57,
#    67,
#    59,
#    68,
#    60,
#    61,
#    70,
#    62,
#    71,
#    63,
#    0,
#    8,
#    16,
#    24,
#    32,
#    40,
#    48,
#    65,
#    57,
#    66,
#    58,
#    67,
#    68,
#    69,
#    61,
#    70,
#    62,
#    71,
#    63,
#    0,
#    8,
#    16,
#    24,
#    32,
#    40,
#    48,
#    64,
#    56,
#    67,
#    68,
#    60,
#    61,
#    70,
#    45,
#    70,
#    45,
#    62,
#    63,
#    0,
#    66,
#    58,
#    8,
#    16,
#    24,
#    68,
#    32,
#    22,
#    57,
#    65,
#    22,
#    40,
#    48],
#   {'th_0': 5.137809,
#    'th_1': 4.7123766,
#    'th_2': 4.712764,
#    'th_3': 1.5488229,
#    'th_4': 0.64107406,
#    'th_5': 3.1415431,
#    'th_6': 1.5708276,
#    'th_7': 4.219248,
#    'th_8': 5.6070247,
#    'th_9': 4.462449,
#    'th_10': 1.1454339,
#    'th_11': 3.1417966,
#    'th_12': 3.3926332,
#    'th_13': 1.5707928,
#    'th_14': 1.5707756,
#    'th_15': 1.5708144,
#    'th_16': 4.71237,
#    'th_17': 1.5707455,
#    'th_18': 1.5707787,
#    'th_19': 1.8207413,
#    'th_20': 4.4492183,
#    'th_21': 0.6464097,
#    'th_22': 1.8652302,
#    'th_23': 0.81193644,
#    'th_24': 1.5708102,
#    'th_25': 1.4373796,
#    'th_26': 1.5707392,
#    'th_27': 1.5708318,
#    'th_28': 3.7250595,
#    'th_29': 7.8539696,
#    'th_30': -0.57282996,
#    'th_31': 1.5707852,
#    'th_32': 2.5687542,
#    'th_33': 2.7492664,
#    'th_34': 4.7121987,
#    'th_35': 4.71212,
#    'th_36': 4.949193,
#    'th_37': 4.979555,
#    'th_38': 4.5004864,
#    'th_39': 2.878393,
#    'th_40': 1.5707377,
#    'th_41': 0.96283245,
#    'th_42': 4.5006585,
#    'th_43': 4.7123427,
#    'th_44': 5.7291183,
#    'th_45': -0.7408508,
#    'th_46': 1.5708992,
#    'th_47': 1.5707963},
#   array(-1.9379661, dtype=float32)],
#  5: [                                                                                                            ┌─────────┐                ┌──────────┐
# (0, 0): ───Rx(0.752π)────────────────@───Rx(1.27π)────────────────@──────────────────────────────────────────────────@────Rx(0.999π)────@─────────────@───────────Rx(0.093π)───Rz(-0.5π)────@──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#                                      │                            │                                                  │                  │             │                                     │
# (0, 1): ───Rx(0.684π)───Rz(0.482π)───X───@───────────Rz(0.277π)───X───@────────────Rx(0.65π)───Rz(0.381π)────────────┼──────────────────┼─────────────X───────────@─────────────────────────X────────────@──────────────────────────────────────────────────────────────────────────────────X──────────Rz(1.47π)───X───────
#                                          │                            │                                              │                  │                         │                                      │                                                                                  │                      │
# (0, 2): ───Rx(0.709π)────────────────────X───────────@────────────────X────────────────────────@─────────────Rx(π)───┼────Rz(0.532π)────┼─────────────────────────X────────────@────────────Rz(0.545π)───X─────────────────────────────────────────────────────────────@────────────────────┼──────────────────────┼───────
#                                                      │                                         │                     │                  │                                      │                                                                                       │                    │                      │
# (0, 3): ───Rx(1.5π)─────Rz(0.5π)─────────────────────X────────────@───Rx(0.717π)───Rz(0.5π)────X─────────────@───────┼────Rx(1.18π)─────┼──────────────────────────────────────X────────────@────────────Rx(1.5π)───────────────────────────X──────────────────────X───X───────@────────────@──────────────────────@───────
#                                                                   │                                          │       │                  │                                                   │                                               │                      │           │
# (0, 4): ───Rx(0.679π)───Rz(-1.78π)────────────────────────────────X───@────────────Rx(1.5π)────Rz(0.497π)────X───────┼────@─────────────┼Rx(1.53π)──────────────────────────────────────────X────────────@──────────Rz(1.64π)───────────────┼──────────────────────┼───────────X────────────Rx(1.5π)───@───────────────────
#                                                                       │                                              │    │             │                                                                │                                  │                      │                                   │
# (0, 5): ──────────────────────────────────────────────────────────────X────────────@───────────Rz(1.71π)─────────────┼────X─────────────┼@────────────Rx(1.53π)───Rz(1.85π)──────────────────────────────X──────────@───────────Rz(1.43π)───┼──────────────────────┼───────────────────────────────────X───────────@───────
#                                                                                    │                                 │                  ││                                                                          │                       │                      │                                               │
# (0, 6): ───Rx(π)───────────────────────────────────────────────────────────────────X───────────@─────────────Rx(0.5π)┼────Rz(1.5π)──────┼X────────────@───────────Rx(1.5π)─────Rz(1.51π)────────────────────────────X───────────@───────────@───────────Rx(1.5π)───@───Rz(π)───Rx(0.748π)──────────────────────────X───@───
#                                                                                                │                     │                  │             │                                                                         │                                                                                      │
# (0, 7): ───────────────────────────────────────────────────────────────────────────────────────X─────────────────────X────Rz(-2.0π)─────X─────────────X───────────Rx(1.56π)────Rz(0.433π)───────────────────────────────────────X───────────Rz(1.49π)──────────────────────────────────────────────────────────────────X───
#                                                                                                             └─────────┘                └──────────┘,
#   array(-1.9056466, dtype=float32),
#   [64,
#    65,
#    57,
#    66,
#    67,
#    59,
#    68,
#    60,
#    70,
#    0,
#    8,
#    16,
#    24,
#    32,
#    40,
#    48,
#    64,
#    57,
#    67,
#    59,
#    68,
#    60,
#    61,
#    70,
#    62,
#    0,
#    8,
#    16,
#    24,
#    6,
#    64,
#    63,
#    6,
#    32,
#    40,
#    48,
#    65,
#    57,
#    66,
#    58,
#    67,
#    68,
#    69,
#    61,
#    70,
#    62,
#    71,
#    63,
#    0,
#    8,
#    16,
#    24,
#    32,
#    40,
#    48,
#    64,
#    56,
#    67,
#    60,
#    61,
#    45,
#    70,
#    45,
#    62,
#    63,
#    0,
#    58,
#    70,
#    8,
#    16,
#    24,
#    68,
#    32,
#    22,
#    57,
#    22,
#    40,
#    48],
#   {'th_0': 2.3609521,
#    'th_1': 2.1488795,
#    'th_2': 1.5137182,
#    'th_3': 2.2273135,
#    'th_4': 4.712174,
#    'th_5': 1.5709435,
#    'th_6': 2.1316473,
#    'th_7': 6.9690614,
#    'th_8': 3.1413925,
#    'th_9': 3.9758334,
#    'th_10': 0.87062097,
#    'th_11': 2.2525806,
#    'th_12': 1.5706528,
#    'th_13': 4.7124157,
#    'th_14': 1.5599661,
#    'th_15': 5.385337,
#    'th_16': 1.5707458,
#    'th_17': 4.712272,
#    'th_18': 3.1384807,
#    'th_19': 6.291767,
#    'th_20': 2.0421565,
#    'th_21': 1.197671,
#    'th_22': 3.1416764,
#    'th_23': 1.6725212,
#    'th_24': 3.7077212,
#    'th_25': 4.822359,
#    'th_26': 4.822308,
#    'th_27': 5.8181524,
#    'th_28': 4.713103,
#    'th_29': 4.7353587,
#    'th_30': 4.8996243,
#    'th_31': 1.3616575,
#    'th_32': 0.2907586,
#    'th_33': -1.5704396,
#    'th_34': 4.7123756,
#    'th_35': 5.159483,
#    'th_36': 4.4918613,
#    'th_37': 4.7123785,
#    'th_38': 3.1415002,
#    'th_39': 4.6894045,
#    'th_40': 1.7124698,
#    'th_41': 2.3499496,
#    'th_42': 4.7119617,
#    'th_43': 4.6109586},
#   array(-1.9379661, dtype=float32)],
#  6: [                                                                               ┌─────────┐               ┌───────────┐
# (0, 0): ───Rx(1.23π)────@───────────────────────────────────────────────────────────────@────Rx(1.0π)─────@──────────────X───────────Rx(0.845π)───Rz(1.71π)─────X───@───────Rz(1.42π)───@─────────────────────────────────────────────────────────────────────────────────────────────────────────────
#                         │                                                               │                 │              │                                      │   │                   │
# (0, 1): ────────────────X───────────────@───Rz(-1.98π)──────────────────────────────────┼─────────────────┼──────────────┼──────────────────────────────────────┼───X───────@───────────X────────────────@────────────────────────────────────────────────────────────────────────────────────────────
#                                         │                                               │                 │              │                                      │           │                            │
# (0, 2): ───Rx(1.68π)────────────────@───X───────────────────────────@───────────────────┼─────────────────┼──────────────@───────────Rz(0.532π)─────────────────@───Rx(π)───X───────────@───Rz(0.693π)───X─────────────────────────────────────────────────────@──────────────────────────────────────
#                                     │                               │                   │                 │                                                                             │                                                                      │
# (0, 3): ───Rx(1.5π)─────Rz(0.5π)────X───@───Rx(0.626π)───Rz(0.5π)───X───────────@───────┼────Rx(1.43π)────┼─────────────────────────────────────────────────────────────────────────────X───@────────────Rx(1.5π)───────────────────X──────────────────────X───X───────────@──────────────────────────
#                                         │                                       │       │                 │                                                                                 │                                       │                      │               │
# (0, 4): ───Rx(0.474π)───Rz(1.44π)───────X───@────────────Rx(0.5π)───Rz(1.5π)────X───────┼────@────────────┼Rx(0.429π)───────────────────────────────────────────────────────────────────────X────────────@──────────Rz(1.34π)───────┼──────────────────────┼───────────────X───Rx(0.5π)───@───────────
#                                             │                                           │    │            │                                                                                              │                          │                      │                              │
# (0, 5): ────────────────────────────────────X────────────@──────────────────────────────┼────X────────────┼@─────────────Rx(1.43π)───Rz(1.17π)───────────────────────────────────────────────────────────X──────────@───────────────┼──────────────────────┼──────────────────────────────X───@───────
#                                                          │                              │                 ││                                                                                                        │               │                      │                                  │
# (0, 6): ───Rx(π)─────────────────────────────────────────X──────────@───────────Rx(1.5π)┼────Rz(0.5π)─────┼X─────────────@───────────Rx(1.5π)─────Rz(1.2π)──────────────────────────────────────────────────────────X───────────@───@───────────Rx(0.5π)───@───Rx(1.51π)──────────────────────X───@───
#                                                                     │                   │                 │              │                                                                                                      │                                                                 │
# (0, 7): ────────────────────────────────────────────────────────────X───────────────────X────Rz(π)────────X──────────────X───────────Rx(0.501π)───Rz(-0.203π)───────────────────────────────────────────────────────────────────X───Rz(1.07π)─────────────────────────────────────────────────────X───
#                                                                                └─────────┘               └───────────┘,
#   array(-1.7903163, dtype=float32),
#   [66,
#    67,
#    59,
#    68,
#    60,
#    70,
#    16,
#    24,
#    32,
#    40,
#    48,
#    64,
#    67,
#    59,
#    68,
#    60,
#    70,
#    62,
#    0,
#    8,
#    57,
#    16,
#    24,
#    6,
#    64,
#    63,
#    6,
#    32,
#    40,
#    48,
#    14,
#    58,
#    64,
#    56,
#    14,
#    66,
#    67,
#    68,
#    69,
#    61,
#    70,
#    62,
#    71,
#    63,
#    0,
#    8,
#    16,
#    24,
#    32,
#    40,
#    48,
#    56,
#    67,
#    60,
#    45,
#    70,
#    45,
#    63,
#    0,
#    58,
#    70,
#    8,
#    16,
#    24,
#    68,
#    32,
#    40,
#    48],
#   {'th_0': 5.2855926,
#    'th_1': 4.7123756,
#    'th_2': 1.570802,
#    'th_3': 1.4900924,
#    'th_4': 4.5174193,
#    'th_5': 3.1411471,
#    'th_6': 3.8523118,
#    'th_7': 1.9664733,
#    'th_8': 1.5708053,
#    'th_9': 1.5707835,
#    'th_10': 4.718923,
#    'th_11': 4.710781,
#    'th_12': 1.5707237,
#    'th_13': 6.331461,
#    'th_14': 3.149048,
#    'th_15': 3.1415982,
#    'th_16': 1.6713225,
#    'th_17': 2.6545267,
#    'th_18': 5.369347,
#    'th_19': 3.1415899,
#    'th_20': 4.5017495,
#    'th_21': 1.3476981,
#    'th_22': 4.489311,
#    'th_23': 3.6668532,
#    'th_24': 4.711874,
#    'th_25': 3.779753,
#    'th_26': 1.5729641,
#    'th_27': -0.63768494,
#    'th_28': 4.4538283,
#    'th_29': 4.711916,
#    'th_30': 4.2082205,
#    'th_31': 1.5707713,
#    'th_32': 3.3670413,
#    'th_33': 2.1755767,
#    'th_34': 4.744138,
#    'th_35': 1.570751},
#   array(-1.9379661, dtype=float32)],
#  7: [(0, 0): ───Rx(1.12π)───@────────────────────X───────────────X───────────@───────Rz(0.674π)───@───────────────────────────────────
#                        │                    │               │           │                    │
# (0, 1): ───────────────X───@───Rz(0.743π)───┼───────────────┼───────────X───────@────────────X───@───────────────────────────────
#                            │                │               │                   │                │
# (0, 2): ───────────────────X───@────────────@───Rz(1.24π)───@───────────Rx(π)───X────────────@───X───@───────────────────────────
#                                │                                                             │       │
# (0, 3): ───Rx(1.0π)────@───────X────────────@────────────────────────────────────────────────X───@───X───@───────────────────────
#                        │                    │                                                    │       │
# (0, 4): ───Rx(π)───────X───@───Rx(π)────────X───@───────────Rz(0.69π)───Rx(π)────────────────────X───@───X───Rx(π)───@───────────
#                            │                    │                                                    │               │
# (0, 5): ───────────────────X───@────────────────X───────────@───────────Rx(π)───Rz(0.838π)───────────X───@───────────X───@───────
#                                │                            │                                            │               │
# (0, 6): ───────────────────────X────────────@───────────────X───────────@───────Rx(π)────────────────────X───@───────────X───@───
#                                             │                           │                                    │               │
# (0, 7): ────────────────────────────────────X───────────────────────────X───────Rx(π)────────────────────────X───────────────X───,
#   array(-1.8470608, dtype=float32),
#   [67,
#    64,
#    68,
#    24,
#    32,
#    40,
#    48,
#    68,
#    0,
#    8,
#    57,
#    16,
#    24,
#    32,
#    40,
#    48,
#    14,
#    58,
#    14,
#    66,
#    60,
#    69,
#    68,
#    61,
#    70,
#    71,
#    0,
#    8,
#    16,
#    24,
#    32,
#    40,
#    48,
#    56,
#    0,
#    8,
#    16,
#    24,
#    68,
#    32,
#    40,
#    48],
#   {'th_0': 3.144471,
#    'th_1': 3.5304155,
#    'th_2': 3.1416817,
#    'th_3': 3.14182,
#    'th_4': 2.3354099,
#    'th_5': 3.8997805,
#    'th_6': 3.1415904,
#    'th_7': 2.1668558,
#    'th_8': 3.1415944,
#    'th_9': 3.141588,
#    'th_10': 2.631147,
#    'th_11': 3.1416368,
#    'th_12': 3.1415923,
#    'th_13': 2.1186914,
#    'th_14': 3.1415832},
#   array(-1.9379661, dtype=float32)],
#  8: [(0, 0): ───Rx(0.894π)───@───────────────────@───────Rz(1.52π)───@─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#                         │                   │                   │
# (0, 1): ────────────────X───@───Rz(1.71π)───X───────@───────────X─────────────────────────────────────────────@───────────────────────────────────────────────────────────────────
#                             │                       │                                                         │
# (0, 2): ────────────────────X───@───────────Rx(π)───X─────────────────────────────────────────────────────@───X─────────────────────────────────@─────────────────────────────────
#                                 │                                                                         │                                     │
# (0, 3): ───Rx(0.998π)───@───────X─────────────────────────────────────────────────────────────────────@───X────────────────────────@────────────X───@─────────────────────────────
#                         │                                                                             │                            │                │
# (0, 4): ───Rx(π)────────X───@───────────────────────X───────────Rx(π)─────────────────────X───Rx(π)───X───@───Rz(0.706π)───Rx(π)───X────────────@───X───Rx(-0.224π)───@───────────
#                             │                       │                                     │               │                                     │                     │
# (0, 5): ────────────────────X───@───────────────────┼─────────────────────────────────────┼───────────────X───@────────────Rx(π)───Rz(0.911π)───X───@─────────────────X───@───────
#                                 │                   │                                     │                   │                                     │                     │
# (0, 6): ────────────────────────X───────────@───────@───────────Rx(0.226π)───Rz(0.205π)───@───────────────────X────────────@────────────────────────X───@─────────────────X───@───
#                                             │                                                                              │                            │                     │
# (0, 7): ────────────────────────────────────X──────────────────────────────────────────────────────────────────────────────X───────Rx(0)────────────────X─────────────────────X───,
#   array(-1.8484699, dtype=float32),
#   [67,
#    64,
#    68,
#    24,
#    32,
#    40,
#    48,
#    46,
#    70,
#    62,
#    68,
#    46,
#    68,
#    0,
#    8,
#    57,
#    16,
#    24,
#    32,
#    40,
#    48,
#    66,
#    60,
#    69,
#    68,
#    61,
#    71,
#    0,
#    8,
#    16,
#    24,
#    32,
#    40,
#    48,
#    56,
#    0,
#    8,
#    16,
#    24,
#    68,
#    32,
#    40,
#    48],
#   {'th_0': 3.1364818,
#    'th_1': 2.8080587,
#    'th_2': 3.1415453,
#    'th_3': 0.70857966,
#    'th_4': 0.6424818,
#    'th_5': 3.1415915,
#    'th_6': 3.1415935,
#    'th_7': 5.3801537,
#    'th_8': 3.1415946,
#    'th_9': 2.219098,
#    'th_10': 3.1415918,
#    'th_11': 3.1415923,
#    'th_12': 2.8615592,
#    'th_13': 1.0905846e-05,
#    'th_14': 4.779516,
#    'th_15': -0.70520306},
#   array(-1.9379661, dtype=float32)],
#  9: [(0, 0): ───Rx(0.894π)───@───────────────────@───────Rz(1.52π)───@─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# ...
# (0, 7): ───────────────────────────────────X─────────────────────────────────────────────────────X───Rz(0.454π)───Rx(0.316π)───Rz(π)────────X───────────────X───────────Rx(1.32π)───────X──────────────────────────X───,
#   array(-1.8520147, dtype=float32),
#   [67,
#    64,
#    24,
#    32,
#    40,
#    48,
#    46,
#    70,
#    62,
#    46,
#    68,
#    0,
#    8,
#    57,
#    16,
#    34,
#    60,
#    68,
#    60,
#    63,
#    71,
#    63,
#    34,
#    24,
#    32,
#    40,
#    48,
#    66,
#    61,
#    71,
#    0,
#    8,
#    16,
#    24,
#    64,
#    32,
#    40,
#    48,
#    0,
#    8,
#    16,
#    24,
#    70,
#    68,
#    32,
#    40,
#    48],
#   {'th_0': -1.7120892e-06,
#    'th_1': 5.9557114,
#    'th_2': 1.5707867,
#    'th_3': 1.570799,
#    'th_4': 4.5435867,
#    'th_5': 1.2529134,
#    'th_6': 5.7036195,
#    'th_7': 3.1415944,
#    'th_8': 2.9671347,
#    'th_9': 1.4247854,
#    'th_10': 0.9936236,
#    'th_11': 3.1415923,
#    'th_12': -2.8772877e-06,
#    'th_13': 5.7320614,
#    'th_14': 4.135236,
#    'th_15': 3.1423068,
#    'th_16': 4.847628,
#    'th_17': 1.5707954},
#   array(-1.9379661, dtype=float32)],
#  17: [(0, 0): ───Rx(1.9π)───@────────────────────@───────Rx(π)───@───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#                       │                    │               │
# (0, 1): ──────────────X───@───Rz(0.399π)───X───────@───────X────────────────────────────────────────────────────────────────────────────────────────────@──────────────────────────────────────────────────────────────
#                           │                        │                                                                                                    │
# (0, 2): ──────────────────X───@────────────Rx(0)───X────────────────────────────────────────────────────────────────────────────────────────────────@───X───@──────────────────────────────────────────────────────────
#                               │                                                                                                                     │       │
# (0, 3): ───Rx(0)──────@───────X─────────────────────────────────────────────────────────────────────────────────────────────────────────────────@───X───@───X───────────────────────@──────────────────────────────────
#                       │                                                                                                                         │       │                           │
# (0, 4): ──────────────X───@────────────────────────X─────────────────────────────X───Rx(1.45π)───@───Rz(1.82π)────Rx(π)────────Rz(0.944π)───@───X───@───X───────────────@───────────X───Rx(0.5π)───@───────────────────
#                           │                        │                             │               │                                          │       │                   │                          │
# (0, 5): ──────────────────X───@────────────────────┼─────────────────────────────┼───────────────┼──────────────────────────────────────────┼───────X───@───Rz(1.82π)───X───────────@──────────────X───────────@───────
#                               │                    │                             │               │                                          │           │                           │                          │
# (0, 6): ──────────────────────X────────────@───────@───────Rx(0.5π)───Rz(0.5π)───@───────────────┼──────────────────────────────────────────┼───────────X───@───────────────────────X───@──────────Rx(1.54π)───X───@───
#                                            │                                                     │                                          │               │                           │                          │
# (0, 7): ───────────────────────────────────X─────────────────────────────────────────────────────X───Rz(0.454π)───Rx(0.316π)───Rz(π)────────X───────────────X───────────Rx(1.32π)───────X──────────────────────────X───,
#   array(-1.8520147, dtype=float32),
#   [67,
#    64,
#    24,
#    32,
#    40,
#    48,
#    46,
#    70,
#    62,
#    46,
#    68,
#    0,
#    8,
#    57,
#    16,
#    34,
#    60,
#    68,
#    60,
#    63,
#    71,
#    63,
#    34,
#    24,
#    32,
#    40,
#    48,
#    66,
#    61,
#    71,
#    0,
#    8,
#    16,
#    24,
#    64,
#    32,
#    40,
#    48,
#    0,
#    8,
#    16,
#    24,
#    70,
#    68,
#    32,
#    40,
#    48],
#   {'th_0': -1.7120892e-06,
#    'th_1': 5.9557114,
#    'th_2': 1.5707867,
#    'th_3': 1.570799,
#    'th_4': 4.5435867,
#    'th_5': 1.2529134,
#    'th_6': 5.7036195,
#    'th_7': 3.1415944,
#    'th_8': 2.9671347,
#    'th_9': 1.4247854,
#    'th_10': 0.9936236,
#    'th_11': 3.1415923,
#    'th_12': -2.8772877e-06,
#    'th_13': 5.7320614,
#    'th_14': 4.135236,
#    'th_15': 3.1423068,
#    'th_16': 4.847628,
#    'th_17': 1.5707954},
#   array(-1.9379661, dtype=float32)],
#  18: [(0, 0): ───Rx(1.9π)───@────────────────────@───────Rx(π)───@───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#                       │                    │               │
# (0, 1): ──────────────X───@───Rz(0.399π)───X───────@───────X────────────────────────────────────────────────────────────────────────────────────────────@──────────────────────────────────────────────────────────────
#                           │                        │                                                                                                    │
# (0, 2): ──────────────────X───@────────────Rx(0)───X────────────────────────────────────────────────────────────────────────────────────────────────@───X───@──────────────────────────────────────────────────────────
#                               │                                                                                                                     │       │
# (0, 3): ───Rx(0)──────@───────X─────────────────────────────────────────────────────────────────────────────────────────────────────────────────@───X───@───X───────────────────────@──────────────────────────────────
#                       │                                                                                                                         │       │                           │
# (0, 4): ──────────────X───@────────────────────────X─────────────────────────────X───Rx(1.45π)───@───Rz(1.82π)────Rx(π)────────Rz(0.944π)───@───X───@───X───────────────@───────────X───Rx(0.5π)───@───────────────────
#                           │                        │                             │               │                                          │       │                   │                          │
# (0, 5): ──────────────────X───@────────────────────┼─────────────────────────────┼───────────────┼──────────────────────────────────────────┼───────X───@───Rz(1.82π)───X───────────@──────────────X───────────@───────
#                               │                    │                             │               │                                          │           │                           │                          │
# (0, 6): ──────────────────────X────────────@───────@───────Rx(0.5π)───Rz(0.5π)───@───────────────┼──────────────────────────────────────────┼───────────X───@───────────────────────X───@──────────Rx(1.54π)───X───@───
#                                            │                                                     │                                          │               │                           │                          │
# (0, 7): ───────────────────────────────────X─────────────────────────────────────────────────────X───Rz(0.454π)───Rx(0.316π)───Rz(π)────────X───────────────X───────────Rx(1.32π)───────X──────────────────────────X───,
#   array(-1.8520147, dtype=float32),
#   [67,
#    64,
#    24,
#    32,
#    40,
#    48,
#    46,
#    70,
#    62,
#    46,
#    68,
#    0,
#    8,
#    57,
#    16,
#    34,
#    60,
#    68,
#    60,
#    63,
#    71,
#    63,
#    34,
#    24,
#    32,
#    40,
#    48,
#    66,
#    61,
#    71,
#    0,
#    8,
#    16,
#    24,
#    64,
#    32,
#    40,
#    48,
#    0,
#    8,
#    16,
#    24,
#    70,
#    68,
#    32,
#    40,
#    48],
#   {'th_0': -1.7120892e-06,
#    'th_1': 5.9557114,
#    'th_2': 1.5707867,
#    'th_3': 1.570799,
#    'th_4': 4.5435867,
#    'th_5': 1.2529134,
#    'th_6': 5.7036195,
#    'th_7': 3.1415944,
#    'th_8': 2.9671347,
#    'th_9': 1.4247854,
#    'th_10': 0.9936236,
#    'th_11': 3.1415923,
#    'th_12': -2.8772877e-06,
#    'th_13': 5.7320614,
#    'th_14': 4.135236,
#    'th_15': 3.1423068,
#    'th_16': 4.847628,
#    'th_17': 1.5707954},
#   array(-1.9379661, dtype=float32)],
#  19: [(0, 0): ───Rx(1.9π)───@────────────────────@───────Rx(π)───@───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#                       │                    │               │
# (0, 1): ──────────────X───@───Rz(0.399π)───X───────@───────X────────────────────────────────────────────────────────────────────────────────────────────@──────────────────────────────────────────────────────────────
#                           │                        │                                                                                                    │
# (0, 2): ──────────────────X───@────────────Rx(0)───X────────────────────────────────────────────────────────────────────────────────────────────────@───X───@──────────────────────────────────────────────────────────
#                               │                                                                                                                     │       │
# (0, 3): ───Rx(0)──────@───────X─────────────────────────────────────────────────────────────────────────────────────────────────────────────────@───X───@───X───────────────────────@──────────────────────────────────
#                       │                                                                                                                         │       │                           │
# (0, 4): ──────────────X───@────────────────────────X─────────────────────────────X───Rx(1.45π)───@───Rz(1.82π)────Rx(π)────────Rz(0.944π)───@───X───@───X───────────────@───────────X───Rx(0.5π)───@───────────────────
#                           │                        │                             │               │                                          │       │                   │                          │
# (0, 5): ──────────────────X───@────────────────────┼─────────────────────────────┼───────────────┼──────────────────────────────────────────┼───────X───@───Rz(1.82π)───X───────────@──────────────X───────────@───────
#                               │                    │                             │               │                                          │           │                           │                          │
# (0, 6): ──────────────────────X────────────@───────@───────Rx(0.5π)───Rz(0.5π)───@───────────────┼──────────────────────────────────────────┼───────────X───@───────────────────────X───@──────────Rx(1.54π)───X───@───
#                                            │                                                     │                                          │               │                           │                          │
# (0, 7): ───────────────────────────────────X─────────────────────────────────────────────────────X───Rz(0.454π)───Rx(0.316π)───Rz(π)────────X───────────────X───────────Rx(1.32π)───────X──────────────────────────X───,
#   array(-1.8520147, dtype=float32),
#   [67,
#    64,
#    24,
#    32,
#    40,
#    48,
#    46,
#    70,
#    62,
#    46,
#    68,
#    0,
#    8,
#    57,
#    16,
#    34,
#    60,
#    68,
#    60,
#    63,
#    71,
#    63,
#    34,
#    24,
#    32,
#    40,
#    48,
#    66,
#    61,
#    71,
#    0,
#    8,
#    16,
#    24,
#    64,
#    32,
#    40,
#    48,
#    0,
#    8,
#    16,
#    24,
#    70,
#    68,
#    32,
#    40,
#    48],
#   {'th_0': -1.7120892e-06,
#    'th_1': 5.9557114,
#    'th_2': 1.5707867,
#    'th_3': 1.570799,
#    'th_4': 4.5435867,
#    'th_5': 1.2529134,
#    'th_6': 5.7036195,
#    'th_7': 3.1415944,
#    'th_8': 2.9671347,
#    'th_9': 1.4247854,
#    'th_10': 0.9936236,
#    'th_11': 3.1415923,
#    'th_12': -2.8772877e-06,
#    'th_13': 5.7320614,
#    'th_14': 4.135236,
#    'th_15': 3.1423068,
#    'th_16': 4.847628,
#    'th_17': 1.5707954},
#   array(-1.9379661, dtype=float32)],
#  20: [(0, 0): ───Rx(1.9π)───@────────────────────@───────Rx(π)───@───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#                       │                    │               │
# (0, 1): ──────────────X───@───Rz(0.399π)───X───────@───────X────────────────────────────────────────────────────────────────────────────────────────────@──────────────────────────────────────────────────────────────
#                           │                        │                                                                                                    │
# (0, 2): ──────────────────X───@────────────Rx(0)───X────────────────────────────────────────────────────────────────────────────────────────────────@───X───@──────────────────────────────────────────────────────────
#                               │                                                                                                                     │       │
# (0, 3): ───Rx(0)──────@───────X─────────────────────────────────────────────────────────────────────────────────────────────────────────────────@───X───@───X───────────────────────@──────────────────────────────────
#                       │                                                                                                                         │       │                           │
# (0, 4): ──────────────X───@────────────────────────X─────────────────────────────X───Rx(1.45π)───@───Rz(1.82π)────Rx(π)────────Rz(0.944π)───@───X───@───X───────────────@───────────X───Rx(0.5π)───@───────────────────
#                           │                        │                             │               │                                          │       │                   │                          │
# (0, 5): ──────────────────X───@────────────────────┼─────────────────────────────┼───────────────┼──────────────────────────────────────────┼───────X───@───Rz(1.82π)───X───────────@──────────────X───────────@───────
#                               │                    │                             │               │                                          │           │                           │                          │
# (0, 6): ──────────────────────X────────────@───────@───────Rx(0.5π)───Rz(0.5π)───@───────────────┼──────────────────────────────────────────┼───────────X───@───────────────────────X───@──────────Rx(1.54π)───X───@───
#                                            │                                                     │                                          │               │                           │                          │
# (0, 7): ───────────────────────────────────X─────────────────────────────────────────────────────X───Rz(0.454π)───Rx(0.316π)───Rz(π)────────X───────────────X───────────Rx(1.32π)───────X──────────────────────────X───,
#   array(-1.8520147, dtype=float32),
#   [67,
#    64,
#    24,
#    32,
#    40,
#    48,
#    46,
#    70,
#    62,
#    46,
#    68,
#    0,
#    8,
#    57,
#    16,
#    34,
#    60,
#    68,
#    60,
#    63,
#    71,
#    63,
#    34,
#    24,
#    32,
#    40,
#    48,
#    66,
#    61,
#    71,
#    0,
#    8,
#    16,
#    24,
#    64,
#    32,
#    40,
#    48,
#    0,
#    8,
#    16,
#    24,
#    70,
#    68,
#    32,
#    40,
#    48],
#   {'th_0': -1.7120892e-06,
#    'th_1': 5.9557114,
#    'th_2': 1.5707867,
#    'th_3': 1.570799,
#    'th_4': 4.5435867,
#    'th_5': 1.2529134,
#    'th_6': 5.7036195,
#    'th_7': 3.1415944,
#    'th_8': 2.9671347,
#    'th_9': 1.4247854,
#    'th_10': 0.9936236,
#    'th_11': 3.1415923,
#    'th_12': -2.8772877e-06,
#    'th_13': 5.7320614,
#    'th_14': 4.135236,
#    'th_15': 3.1423068,
#    'th_16': 4.847628,
#    'th_17': 1.5707954},
#   array(-1.9379661, dtype=float32)]}

# %%
circ, energy, indexed_circuit,resolver, lowest_energy = evaluator.evolution[len(evaluator.evolution.keys())-1]

# %%
energy
# Out:
# array(-1.8520147, dtype=float32)

# %%
from utilities.variational import VQE
from utilities.evaluator import Evaluator
from utilities.idinserter import IdInserter
from utilities.simplifier import Simplifier
from utilities.unitary_killer import UnitaryMurder

bond=1.5
problem_config ={"problem" : "H4", 
                               "geometry": [('H', (0., 0., 0.)), ('H', (0., 0., bond)), ('H', (0., 0., 2*bond)), ('H', (0., 0., 3*bond))], 
                               "multiplicity":1, "charge":0, "basis":"sto-3g"}
q=8
vqe_handler = VQE(n_qubits=q, lr=0.01, epochs=2000,
                    noise_config={}, problem_config=problem_config,
                    patience=200, random_perturbations=True, 
                  return_lower_bound=0, optimizer="adam")

iid = IdInserter(n_qubits=len(vqe_handler.qubits))
Simp = Simplifier(n_qubits=len(vqe_handler.qubits))
killer = UnitaryMurder(vqe_handler, noise_config={})

# %%
energy, symbol_to_value, training_evolution = vqe_handler.vqe(indexed_circuit) #compute energy
plt.plot(training_evolution.history["energy"])

# %%
circuit = vqe_handler.give_circuit(indexed_circuit)[0]
circuit.operation_at(0)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-56-ac1dc5de37cb> in <module>
#       1 circuit = vqe_handler.give_circuit(indexed_circuit)[0]
# ----> 2 circuit.operation_at(0)
#
# TypeError: operation_at() missing 1 required positional argument: 'moment_index'

# %%
import cirq

# %%
list(circuit.moments)[0].operates_on_single_qubit(vqe_handler.qubits[-1])
# Out:
# False

# %%
iid.inserter(indexed_circuit,resolver,-1)
